# %% [markdown]
# End-to-End Supervised Learning Project!

# %% [markdown]
# # **PROJECT:** Analysis of New York City's Energy and Water Data Using Linear Learner Model on Amazon SageMaker

# %% [markdown]
# # Contents
#
# 1. Introduction
# 2. Data Setup
# 3. Data Preparation/Preprocessing
# 4. Training the model
# 5. Batch Transformation for Offline Inferences
# 6. DataCapture Configuration, and Model deployment for Real-time inferences
# 7. Model Monitoring
# 8. Clean up

# %% [markdown]
# # Introduction
#
# This Notebook uses Linear Learner algorithm on Amazon Sagemaker to train, host, maintain a regression model. The data used were obtained from NYC OpenData Portal

# %% [markdown]
# # Setup
#
# This notebook was tested in Amazon SageMaker Studio on a ml.t3.medium instance with Python 3 (Data Science) kernel.

# %% [markdown]
# # Dataset and Data Ingestion

# %%
# Importing Libraries

# Data processing

import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# Visualization

# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# Machine learning

from sklearn.model_selection import train_test_split
from sklearn import metrics
import sklearn.feature_selection as fs
from statsmodels.stats.outliers_influence import variance_inflation_factor
import sklearn.metrics as metrics
from sklearn.datasets import *
import sklearn.model_selection
from sklearn.datasets import make_regression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.inspection import permutation_importance
import xgboost
from xgboost import XGBRegressor

# SageMaker

from time import sleep
import boto3
import sagemaker
import s3fs
import os
from time import sleep, gmtime, strftime
import json
import sys
import subprocess
import pkg_resources
import io
from urllib.parse import urlparse

# SageMaker Experiment

import time
from time import strftime

#!pip install sagemaker-experiments --> if it isn't installed.
from sagemaker.analytics import ExperimentAnalytics
from smexperiments.experiment import Experiment
from smexperiments.trial import Trial
from smexperiments.trial_component import TrialComponent
from smexperiments.tracker import Tracker

# %%
# To ensure the latest sagemaker is been used.

import sagemaker
print(sagemaker.__version__)
# Out:
# 2.46.1

# %%
data_bucket = 'just-abdul-aws' #Defining bucket name
subfolder = 'NewYork' #Defining sub-folder name
dataset = '2018.csv'

# %%
role = sagemaker.get_execution_role()
sess = sagemaker.Session()
s3 = s3fs.S3FileSystem(anon=False)
sm = boto3.Session().client('sagemaker')

# %%
df = pd.read_csv(f's3://{data_bucket}/{subfolder}/{dataset}')

# %% [markdown]
# # Understanding the data

# %%
df.head(5)
# Out:
#   Order  Property Id        Property Name  \
# 0     1         7365                 1155
# 1     2         8139                  200
# 2     3         8604                  114
# 3     4         8841                  733
# 4     5        11809  Conde Nast Building
#
#                     Parent Property Id                 Parent Property Name  \
# 0  Not Applicable: Standalone Property  Not Applicable: Standalone Property
# 1  Not Applicable: Standalone Property  Not Applicable: Standalone Property
# 2  Not Applicable: Standalone Property  Not Applicable: Standalone Property
# 3  Not Applicable: Standalone Property  Not Applicable: Standalone Property
# 4  Not Applicable: Standalone Property  Not Applicable: Standalone Property
#
#   City Building BBL - 10 digits  \
# 0            No      1009970029
# 1            No      1013150001
# 2            No      1009990019
# 3            No      1013190047
# 4            No      1009950005
#
#   NYC Borough, Block and Lot (BBL) self - reported  \
# 0                                       1009970029
# 1                                       1013150001
# 2                                       1009990019
# 3                                       1013190047
# 4                                       1009950005
#
#   NYC Building Identification Number (BIN)      Address 1 (self - reported)  \
# 0                                  1022631  1155  Avenue  of  the  Americas
# 1                                  1037545             200  East  42nd  St.
# 2                                  1022667              114  West  47th  st
# 3                                  1037596               733  Third  Avenue
# 4                                  1085682                   4 Times Square
#
#    ... Water Use (All Water Sources) (kgal)  \
# 0  ...                        Not Available
# 1  ...                               7252.6
# 2  ...                        Not Available
# 3  ...                        Not Available
# 4  ...                        Not Available
#
#    Water Use Intensity (All Water Sources) (gal/ft²) Water Required?  \
# 0                                      Not Available              No
# 1                                              18.87             Yes
# 2                                      Not Available              No
# 3                                      Not Available              No
# 4                                      Not Available             NaN
#
#           Generation Date   Latitude  Longitude Community Board  \
# 0  04/30/2019 11:53:26 AM  40.756631 -73.982826           105.0
# 1  04/30/2019 11:53:27 AM        NaN        NaN             NaN
# 2  04/30/2019 11:53:27 AM        NaN        NaN             NaN
# 3  04/30/2019 11:53:27 AM  40.753074 -73.972753           106.0
# 4  04/30/2019 11:53:27 AM  40.756181 -73.986244           105.0
#
#   Council District Census Tract                      NTA
# 0              4.0          119    Midtown-Midtown South
# 1              NaN          NaN                      NaN
# 2              NaN          NaN                      NaN
# 3              4.0           90  Turtle Bay-East Midtown
# 4              4.0          119    Midtown-Midtown South
#
# [5 rows x 67 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25939 entries, 0 to 25938
# Data columns (total 67 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Order                                                       25939 non-null  object
#  1   Property Id                                                 25939 non-null  int64
#  2   Property Name                                               25939 non-null  object
#  3   Parent Property Id                                          25939 non-null  object
#  4   Parent Property Name                                        25939 non-null  object
#  5   City Building                                               25939 non-null  object
#  6   BBL - 10 digits                                             25939 non-null  object
#  7   NYC Borough, Block and Lot (BBL) self - reported            25939 non-null  object
#  8   NYC Building Identification Number (BIN)                    25939 non-null  object
#  9   Address 1 (self - reported)                                 25939 non-null  object
#  10  Address 2 (self - reported)                                 25939 non-null  object
#  11  Postcode                                                    25892 non-null  float64
#  12  Street Number                                               25910 non-null  object
#  13  Street Name                                                 25845 non-null  object
#  14  Borough                                                     25939 non-null  object
#  15  DOF Gross Floor Area  (ft²)                                 19355 non-null  object
#  16  Self-Reported Gross Floor Area (ft²)                        25939 non-null  object
#  17  Primary Property Type - Self Selected                       25939 non-null  object
#  18  List of All Property Use Types at Property                  25939 non-null  object
#  19  Largest Property Use Type                                   25939 non-null  object
#  20  Largest Property Use Type - Gross Floor Area (ft²)          25932 non-null  object
#  21  2nd Largest Property Use Type                               25939 non-null  object
#  22  2nd Largest Property Use - Gross Floor Area (ft²)           25939 non-null  object
#  23  3rd Largest Property Use Type                               25939 non-null  object
#  24  3rd Largest Property Use Type - Gross Floor Area (ft²)      25939 non-null  object
#  25  Year Built                                                  25939 non-null  object
#  26  Number of Buildings                                         25939 non-null  int64
#  27  Occupancy                                                   25939 non-null  int64
#  28  Metered Areas (Energy)                                      25939 non-null  object
#  29  Metered Areas  (Water)                                      25939 non-null  object
#  30  ENERGY STAR Score                                           25939 non-null  object
#  31  Source EUI (kBtu/ft²)                                       25939 non-null  object
#  32  Weather Normalized Source EUI (kBtu/ft²)                    25939 non-null  object
#  33  Site EUI (kBtu/ft²)                                         25939 non-null  object
#  34  Weather Normalized Site EUI (kBtu/ft²)                      25939 non-null  object
#  35  Weather Normalized Site Electricity Intensity (kWh/ft²)     25939 non-null  object
#  36  Weather Normalized Site Natural Gas Intensity (therms/ft²)  25939 non-null  object
#  37  Fuel Oil #1 Use (kBtu)                                      25939 non-null  object
#  38  Fuel Oil #2 Use (kBtu)                                      25939 non-null  object
#  39  Fuel Oil #4 Use (kBtu)                                      25939 non-null  object
#  40  Fuel Oil #5 & 6 Use (kBtu)                                  25939 non-null  object
#  41  Diesel #2 Use (kBtu)                                        25939 non-null  object
#  42  Kerosene Use (kBtu)                                         25939 non-null  object
#  43  Propane Use (kBtu)                                          25939 non-null  object
#  44  District Steam Use (kBtu)                                   25939 non-null  object
#  45  District Hot Water Use (kBtu)                               25939 non-null  object
#  46  District Chilled Water Use (kBtu)                           25939 non-null  object
#  47  Natural Gas Use (kBtu)                                      25939 non-null  object
#  48  Weather Normalized Site Natural Gas Use (therms)            25939 non-null  object
#  49  Electricity Use - Grid Purchase (kBtu)                      25939 non-null  object
#  50  Electricity Use - Grid Purchase (kWh)                       25939 non-null  object
#  51  Weather Normalized Site Electricity (kWh)                   25939 non-null  object
#  52  Annual Maximum Demand (kW)                                  25939 non-null  object
#  53  Annual Maximum Demand (MM/YYYY)                             25939 non-null  object
#  54  Total GHG Emissions (Metric Tons CO2e)                      25939 non-null  object
#  55  Direct GHG Emissions (Metric Tons CO2e)                     25939 non-null  object
#  56  Indirect GHG Emissions (Metric Tons CO2e)                   25939 non-null  object
#  57  Water Use (All Water Sources) (kgal)                        25939 non-null  object
#  58  Water Use Intensity (All Water Sources) (gal/ft²)           25939 non-null  object
#  59  Water Required?                                             19355 non-null  object
#  60  Generation Date                                             25939 non-null  object
#  61  Latitude                                                    16834 non-null  float64
#  62  Longitude                                                   16834 non-null  float64
#  63  Community Board                                             16834 non-null  float64
#  64  Council District                                            16834 non-null  float64
#  65  Census Tract                                                16834 non-null  object
#  66  NTA                                                         16834 non-null  object
# dtypes: float64(5), int64(3), object(59)
# memory usage: 13.3+ MB

# %%
df.describe()
# Out:
#         Property Id      Postcode  Number of Buildings     Occupancy  \
# count  2.593900e+04  2.589200e+04         25939.000000  25939.000000
# mean   5.045627e+06  1.842241e+05             1.240063     98.164347
# std    1.804315e+06  4.311858e+06             3.430990      9.459872
# min    7.365000e+03  1.222000e+03             0.000000      0.000000
# 25%    3.111576e+06  1.002800e+04             1.000000    100.000000
# 50%    5.950838e+06  1.046000e+04             1.000000    100.000000
# 75%    6.631356e+06  1.122000e+04             1.000000    100.000000
# max    8.729534e+06  1.143423e+08           161.000000    100.000000
#
#            Latitude     Longitude  Community Board  Council District
# count  16834.000000  16834.000000     16834.000000      16834.000000
# mean      40.742200    -73.928984       264.651123         22.439408
# std        0.080676      0.069150       114.613441         14.463578
# min       40.509037    -74.244118       101.000000          1.000000
# 25%       40.685378    -73.975683       202.000000         10.000000
# 50%       40.738306    -73.932690       302.000000         21.000000
# 75%       40.815921    -73.889371       401.000000         35.000000
# max       40.912869    -73.700935       503.000000         51.000000

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# Most of the data are in Categorical form, some features have no correlation nor add value to the target variable (Total GHG) thus need cleaning

# %% [markdown]
# # Data Cleaning/Preparation

# %%
df = df.replace('Not Available', None)

# %%
# Removing the character in the data.

df[['DOF Gross Floor Area  (ft²)', 'Year Built']] = df[['DOF Gross Floor Area  (ft²)', 'Year Built']].replace(',','', regex=True)

# %%
# Selecting Obj type which are actually numbers

cols = ['NYC Building Identification Number (BIN)','Postcode','DOF Gross Floor Area  (ft²)','Year Built','ENERGY STAR Score','Source EUI (kBtu/ft²)','Weather Normalized Site EUI (kBtu/ft²)','Site EUI (kBtu/ft²)','Weather Normalized Source EUI (kBtu/ft²)','Weather Normalized Site Electricity Intensity (kWh/ft²)','Weather Normalized Site Natural Gas Intensity (therms/ft²)','Natural Gas Use (kBtu)','Weather Normalized Site Natural Gas Use (therms)','Electricity Use - Grid Purchase (kWh)','Weather Normalized Site Electricity (kWh)','Total GHG Emissions (Metric Tons CO2e)','Direct GHG Emissions (Metric Tons CO2e)','Indirect GHG Emissions (Metric Tons CO2e)','Water Use (All Water Sources) (kgal)','Water Use Intensity (All Water Sources) (gal/ft²)']

# %%
# Selecting Obj type which are actually numbers

cols2 = ['BBL - 10 digits','Street Number', 'Self-Reported Gross Floor Area (ft²)','Largest Property Use Type - Gross Floor Area (ft²)','2nd Largest Property Use - Gross Floor Area (ft²)','3rd Largest Property Use Type - Gross Floor Area (ft²)','Fuel Oil #1 Use (kBtu)','Fuel Oil #2 Use (kBtu)','Fuel Oil #5 & 6 Use (kBtu)','Fuel Oil #2 Use (kBtu)','Diesel #2 Use (kBtu)','Propane Use (kBtu)','District Steam Use (kBtu)','District Chilled Water Use (kBtu)','Electricity Use - Grid Purchase (kBtu)','Annual Maximum Demand (kW)']

# %%
# Converting Obj type to Num

col = cols + cols2
df[col] = df[col].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
Sum = df.isnull().sum()
Percentage = ( df.isnull().sum()/df.isnull().count())

nulls = pd.concat([Sum,Percentage], axis =1, keys= ['Sum', 'Percentage']).sort_values(by='Sum', ascending=False).head(30)
nulls
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
#                                                       Sum  Percentage
# Largest Property Use Type - Gross Floor Area (ft²)  25936    0.999884
# Self-Reported Gross Floor Area (ft²)                25934    0.999807
# Propane Use (kBtu)                                  15939    0.614480
# Longitude                                            9105    0.351016
# Latitude                                             9105    0.351016
# NTA                                                  9105    0.351016
# Community Board                                      9105    0.351016
# Council District                                     9105    0.351016
# Census Tract                                         9105    0.351016
# DOF Gross Floor Area  (ft²)                          6584    0.253826
# Water Required?                                      6584    0.253826
# Street Number                                        4904    0.189059
# Fuel Oil #1 Use (kBtu)                               4139    0.159567
# NYC Building Identification Number (BIN)             1954    0.075331
# Fuel Oil #5 & 6 Use (kBtu)                           1358    0.052354
# BBL - 10 digits                                       258    0.009946
# Annual Maximum Demand (kW)                            115    0.004433
# Street Name                                            94    0.003624
# Postcode                                               47    0.001812
# District Chilled Water Use (kBtu)                      32    0.001234
# Diesel #2 Use (kBtu)                                   26    0.001002
# Fuel Oil #2 Use (kBtu)                                  6    0.000231
# Weather Normalized Site Natural Gas Intensity (...      2    0.000077
# Weather Normalized Site Natural Gas Use (therms)        2    0.000077
# Natural Gas Use (kBtu)                                  2    0.000077
# 3rd Largest Property Use Type - Gross Floor Are...      1    0.000039
# Water Use Intensity (All Water Sources) (gal/ft²)       1    0.000039
# Water Use (All Water Sources) (kgal)                    1    0.000039
# Annual Maximum Demand (MM/YYYY)                         0    0.000000
# District Steam Use (kBtu)                               0    0.000000

# %% [markdown]
# A 30% missing value threshold is selected. columns with more than 30% missing values will be dropped.

# %%
#Selecting the columns with more than 30% missing values

remove = nulls[nulls['Percentage']>=0.30]
remove.index.name = 'Features' # Renames the index to 'Features'
remove.reset_index(level=0, inplace=True) # Re-index's the dataframe, turning 'Features' into a column
remove
# Out:
#                                             Features    Sum  Percentage
# 0  Largest Property Use Type - Gross Floor Area (...  25936    0.999884
# 1               Self-Reported Gross Floor Area (ft²)  25934    0.999807
# 2                                 Propane Use (kBtu)  15939    0.614480
# 3                                          Longitude   9105    0.351016
# 4                                           Latitude   9105    0.351016
# 5                                                NTA   9105    0.351016
# 6                                    Community Board   9105    0.351016
# 7                                   Council District   9105    0.351016
# 8                                       Census Tract   9105    0.351016

# %%
remove['Features'].tolist()
# Out:
# ['Largest Property Use Type - Gross Floor Area (ft²)',
#  'Self-Reported Gross Floor Area (ft²)',
#  'Propane Use (kBtu)',
#  'Longitude',
#  'Latitude',
#  'NTA',
#  'Community Board',
#  'Council District',
#  'Census Tract']

# %%
#Dropping the columns with more than 30% missing values

df = df.drop(remove['Features'].tolist(), axis=1)

# %%
# Dropping other columns that aren't useful

df = df.drop(['Order','Property Name', 'Parent Property Id','Parent Property Name', 'Property Id','BBL - 10 digits','NYC Building Identification Number (BIN)','Postcode','Street Number', 'NYC Borough, Block and Lot (BBL) self - reported','Address 1 (self - reported)','Water Required?', 'Address 2 (self - reported)','Street Name','Fuel Oil #4 Use (kBtu)','Kerosene Use (kBtu)', 'Annual Maximum Demand (MM/YYYY)', 'Generation Date','District Hot Water Use (kBtu)'], axis=1)

# %%
df_obj = df.select_dtypes(include=['object'])
df_num = df.select_dtypes(exclude=['object'])

# %%
df_num
# Out:
#        DOF Gross Floor Area  (ft²)  \
# 0                         734668.0
# 1                         380000.0
# 2                         646995.0
# 3                         405399.0
# 4                              NaN
# ...                            ...
# 25934                     375225.0
# 25935                     375225.0
# 25936                      27424.0
# 25937                      43073.0
# 25938                      38912.0
#
#        2nd Largest Property Use - Gross Floor Area (ft²)  \
# 0                                                 5227.0
# 1                                                15789.0
# 2                                                15789.0
# 3                                                15789.0
# 4                                                62864.0
# ...                                                  ...
# 25934                                             9980.0
# 25935                                             9980.0
# 25936                                             9980.0
# 25937                                             9980.0
# 25938                                             9980.0
#
#        3rd Largest Property Use Type - Gross Floor Area (ft²)  Year Built  \
# 0                                                    NaN           1982.0
# 1                                                 2115.0           1956.0
# 2                                                 2115.0           1989.0
# 3                                                 2115.0           1961.0
# 4                                                 2115.0           1999.0
# ...                                                  ...              ...
# 25934                                             8510.0           1972.0
# 25935                                             8510.0           1973.0
# 25936                                             8510.0           2015.0
# 25937                                             8510.0           1900.0
# 25938                                             8510.0           1925.0
#
#        Number of Buildings  Occupancy  ENERGY STAR Score  \
# 0                        1         40               79.0
# 1                        1        100               62.0
# 2                        1         95               66.0
# 3                        1        100               64.0
# 4                        1        100               42.0
# ...                    ...        ...                ...
# 25934                    1         75              100.0
# 25935                    2         75               27.0
# 25936                    1         90                6.0
# 25937                    1        100                6.0
# 25938                    1        100                6.0
#
#        Source EUI (kBtu/ft²)  Weather Normalized Source EUI (kBtu/ft²)  \
# 0                      110.9                                     110.9
# 1                      193.4                                     190.6
# 2                      155.6                                     154.6
# 3                      181.5                                     178.2
# 4                      226.1                                     227.3
# ...                      ...                                       ...
# 25934                   20.4                                      20.4
# 25935                  134.7                                     133.0
# 25936                  219.7                                     218.5
# 25937                  219.7                                     218.5
# 25938                  363.4                                     392.8
#
#        Site EUI (kBtu/ft²)  ...  \
# 0                     45.7  ...
# 1                    101.0  ...
# 2                     70.3  ...
# 3                     97.1  ...
# 4                    100.4  ...
# ...                    ...  ...
# 25934                 19.4  ...
# 25935                 86.0  ...
# 25936                107.1  ...
# 25937                107.1  ...
# 25938                299.4  ...
#
#        Weather Normalized Site Natural Gas Use (therms)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                9632.3
# 3                                                9632.3
# 4                                              389906.7
# ...                                                 ...
# 25934                                           36466.0
# 25935                                          228877.1
# 25936                                           12557.0
# 25937                                           12557.0
# 25938                                            8952.0
#
#        Electricity Use - Grid Purchase (kBtu)  \
# 0                                  23995341.5
# 1                                  17308898.1
# 2                                  25783057.2
# 3                                  15906223.2
# 4                                 109258703.4
# ...                                       ...
# 25934                                821766.1
# 25935                               9519753.3
# 25936                               1680788.6
# 25937                                686541.0
# 25938                               1306441.2
#
#        Electricity Use - Grid Purchase (kWh)  \
# 0                                  7032631.5
# 1                                  5072947.2
# 2                                  7556580.9
# 3                                  4661846.8
# 4                                 32021890.4
# ...                                      ...
# 25934                               240845.8
# 25935                              2790079.8
# 25936                               492610.9
# 25937                               201213.6
# 25938                               382896.0
#
#        Weather Normalized Site Electricity (kWh)  Annual Maximum Demand (kW)  \
# 0                                      7032631.5                         NaN
# 1                                      5055495.0                         NaN
# 2                                      7446568.4                         NaN
# 3                                      4612102.7                         NaN
# 4                                     32021890.4                         NaN
# ...                                          ...                         ...
# 25934                                   240845.8                         0.0
# 25935                                  2709471.4                       687.8
# 25936                                   489166.9                       687.8
# 25937                                   201213.6                       687.8
# 25938                                   382896.0                       687.8
#
#        Total GHG Emissions (Metric Tons CO2e)  \
# 0                                      2520.9
# 1                                      2895.1
# 2                                      3155.8
# 3                                      2826.2
# 4                                     12179.3
# ...                                       ...
# 25934                                   193.7
# 25935                                  2014.0
# 25936                                   209.0
# 25937                                   209.0
# 25938                                   859.4
#
#        Direct GHG Emissions (Metric Tons CO2e)  \
# 0                                          0.0
# 1                                          0.0
# 2                                         51.2
# 3                                          0.0
# 4                                       1991.7
# ...                                        ...
# 25934                                    193.7
# 25935                                   1207.8
# 25936                                     66.7
# 25937                                     66.7
# 25938                                    748.8
#
#        Indirect GHG Emissions (Metric Tons CO2e)  \
# 0                                         2520.9
# 1                                         2895.1
# 2                                         3104.7
# 3                                         2826.2
# 4                                        10187.6
# ...                                          ...
# 25934                                        0.0
# 25935                                      806.2
# 25936                                      142.3
# 25937                                       58.1
# 25938                                      110.6
#
#        Water Use (All Water Sources) (kgal)  \
# 0                                       NaN
# 1                                    7252.6
# 2                                    7252.6
# 3                                    7252.6
# 4                                    7252.6
# ...                                     ...
# 25934                                 294.2
# 25935                               18450.8
# 25936                                2675.8
# 25937                                  10.5
# 25938                              286426.0
#
#        Water Use Intensity (All Water Sources) (gal/ft²)
# 0                                                    NaN
# 1                                                  18.87
# 2                                                  18.87
# 3                                                  18.87
# 4                                                  18.87
# ...                                                  ...
# 25934                                               8.93
# 25935                                              49.17
# 25936                                              97.57
# 25937                                               0.24
# 25938                                            7360.87
#
# [25939 rows x 30 columns]

# %% [markdown]
# # Dealing with NaN values.

# %% [markdown]
# Nan values will be replaced with the median of that feature/column

# %%
# Creating a pipeline that handles NaNs as well as transforms data using standard scaler.

num_pipeline = Pipeline([('imputer', SimpleImputer(strategy="median"))])

# %%
df_pipeline = num_pipeline.fit_transform(df_num)

# %%
df_pipe = pd.DataFrame(df_pipeline, columns=df_num.columns,index=df_num.index)

# %%
df_pipe
# Out:
#        DOF Gross Floor Area  (ft²)  \
# 0                         734668.0
# 1                         380000.0
# 2                         646995.0
# 3                         405399.0
# 4                          56986.0
# ...                            ...
# 25934                     375225.0
# 25935                     375225.0
# 25936                      27424.0
# 25937                      43073.0
# 25938                      38912.0
#
#        2nd Largest Property Use - Gross Floor Area (ft²)  \
# 0                                                 5227.0
# 1                                                15789.0
# 2                                                15789.0
# 3                                                15789.0
# 4                                                62864.0
# ...                                                  ...
# 25934                                             9980.0
# 25935                                             9980.0
# 25936                                             9980.0
# 25937                                             9980.0
# 25938                                             9980.0
#
#        3rd Largest Property Use Type - Gross Floor Area (ft²)  Year Built  \
# 0                                                 5712.0           1982.0
# 1                                                 2115.0           1956.0
# 2                                                 2115.0           1989.0
# 3                                                 2115.0           1961.0
# 4                                                 2115.0           1999.0
# ...                                                  ...              ...
# 25934                                             8510.0           1972.0
# 25935                                             8510.0           1973.0
# 25936                                             8510.0           2015.0
# 25937                                             8510.0           1900.0
# 25938                                             8510.0           1925.0
#
#        Number of Buildings  Occupancy  ENERGY STAR Score  \
# 0                      1.0       40.0               79.0
# 1                      1.0      100.0               62.0
# 2                      1.0       95.0               66.0
# 3                      1.0      100.0               64.0
# 4                      1.0      100.0               42.0
# ...                    ...        ...                ...
# 25934                  1.0       75.0              100.0
# 25935                  2.0       75.0               27.0
# 25936                  1.0       90.0                6.0
# 25937                  1.0      100.0                6.0
# 25938                  1.0      100.0                6.0
#
#        Source EUI (kBtu/ft²)  Weather Normalized Source EUI (kBtu/ft²)  \
# 0                      110.9                                     110.9
# 1                      193.4                                     190.6
# 2                      155.6                                     154.6
# 3                      181.5                                     178.2
# 4                      226.1                                     227.3
# ...                      ...                                       ...
# 25934                   20.4                                      20.4
# 25935                  134.7                                     133.0
# 25936                  219.7                                     218.5
# 25937                  219.7                                     218.5
# 25938                  363.4                                     392.8
#
#        Site EUI (kBtu/ft²)  ...  \
# 0                     45.7  ...
# 1                    101.0  ...
# 2                     70.3  ...
# 3                     97.1  ...
# 4                    100.4  ...
# ...                    ...  ...
# 25934                 19.4  ...
# 25935                 86.0  ...
# 25936                107.1  ...
# 25937                107.1  ...
# 25938                299.4  ...
#
#        Weather Normalized Site Natural Gas Use (therms)  \
# 0                                               30269.4
# 1                                               30269.4
# 2                                                9632.3
# 3                                                9632.3
# 4                                              389906.7
# ...                                                 ...
# 25934                                           36466.0
# 25935                                          228877.1
# 25936                                           12557.0
# 25937                                           12557.0
# 25938                                            8952.0
#
#        Electricity Use - Grid Purchase (kBtu)  \
# 0                                  23995341.5
# 1                                  17308898.1
# 2                                  25783057.2
# 3                                  15906223.2
# 4                                 109258703.4
# ...                                       ...
# 25934                                821766.1
# 25935                               9519753.3
# 25936                               1680788.6
# 25937                                686541.0
# 25938                               1306441.2
#
#        Electricity Use - Grid Purchase (kWh)  \
# 0                                  7032631.5
# 1                                  5072947.2
# 2                                  7556580.9
# 3                                  4661846.8
# 4                                 32021890.4
# ...                                      ...
# 25934                               240845.8
# 25935                              2790079.8
# 25936                               492610.9
# 25937                               201213.6
# 25938                               382896.0
#
#        Weather Normalized Site Electricity (kWh)  Annual Maximum Demand (kW)  \
# 0                                      7032631.5                       152.0
# 1                                      5055495.0                       152.0
# 2                                      7446568.4                       152.0
# 3                                      4612102.7                       152.0
# 4                                     32021890.4                       152.0
# ...                                          ...                         ...
# 25934                                   240845.8                         0.0
# 25935                                  2709471.4                       687.8
# 25936                                   489166.9                       687.8
# 25937                                   201213.6                       687.8
# 25938                                   382896.0                       687.8
#
#        Total GHG Emissions (Metric Tons CO2e)  \
# 0                                      2520.9
# 1                                      2895.1
# 2                                      3155.8
# 3                                      2826.2
# 4                                     12179.3
# ...                                       ...
# 25934                                   193.7
# 25935                                  2014.0
# 25936                                   209.0
# 25937                                   209.0
# 25938                                   859.4
#
#        Direct GHG Emissions (Metric Tons CO2e)  \
# 0                                          0.0
# 1                                          0.0
# 2                                         51.2
# 3                                          0.0
# 4                                       1991.7
# ...                                        ...
# 25934                                    193.7
# 25935                                   1207.8
# 25936                                     66.7
# 25937                                     66.7
# 25938                                    748.8
#
#        Indirect GHG Emissions (Metric Tons CO2e)  \
# 0                                         2520.9
# 1                                         2895.1
# 2                                         3104.7
# 3                                         2826.2
# 4                                        10187.6
# ...                                          ...
# 25934                                        0.0
# 25935                                      806.2
# 25936                                      142.3
# 25937                                       58.1
# 25938                                      110.6
#
#        Water Use (All Water Sources) (kgal)  \
# 0                                    3242.1
# 1                                    7252.6
# 2                                    7252.6
# 3                                    7252.6
# 4                                    7252.6
# ...                                     ...
# 25934                                 294.2
# 25935                               18450.8
# 25936                                2675.8
# 25937                                  10.5
# 25938                              286426.0
#
#        Water Use Intensity (All Water Sources) (gal/ft²)
# 0                                                  49.17
# 1                                                  18.87
# 2                                                  18.87
# 3                                                  18.87
# 4                                                  18.87
# ...                                                  ...
# 25934                                               8.93
# 25935                                              49.17
# 25936                                              97.57
# 25937                                               0.24
# 25938                                            7360.87
#
# [25939 rows x 30 columns]

# %% [markdown]
# # Dealing with Cat datatype

# %%
le=LabelEncoder()

for col in df_obj.columns.values:
    # Encoding only categorical variables
    if df_obj[col].dtypes=='object':
        # Using whole data to form an exhaustive list of levels
        data=df_obj[col]
        le.fit(data.values)
        df_obj[col]=le.transform(df_obj[col])

# %%
df_obj
# Out:
#        City Building  Borough  Primary Property Type - Self Selected  \
# 0                  0        2                                     33
# 1                  0        2                                     33
# 2                  0        2                                     13
# 3                  0        2                                     33
# 4                  0        2                                     33
# ...              ...      ...                                    ...
# 25934              0        0                                     30
# 25935              0        0                                     30
# 25936              0        1                                     19
# 25937              0        2                                     30
# 25938              0        0                                     28
#
#        List of All Property Use Types at Property  Largest Property Use Type  \
# 0                                              86                         32
# 1                                              97                         32
# 2                                             325                         13
# 3                                             889                         32
# 4                                             973                         32
# ...                                           ...                        ...
# 25934                                         679                         29
# 25935                                         679                         29
# 25936                                         478                         19
# 25937                                         679                         29
# 25938                                         987                         33
#
#        2nd Largest Property Use Type  3rd Largest Property Use Type  \
# 0                                  2                             24
# 1                                 50                              2
# 2                                 50                              2
# 3                                 50                              2
# 4                                 50                              2
# ...                              ...                            ...
# 25934                             29                             25
# 25935                             29                             25
# 25936                             29                             25
# 25937                             29                             25
# 25938                             29                             25
#
#        Metered Areas (Energy)  Metered Areas  (Water)
# 0                           8                       2
# 1                           8                       5
# 2                           8                       5
# 3                           8                       5
# 4                           8                       5
# ...                       ...                     ...
# 25934                       8                       5
# 25935                       8                       5
# 25936                       8                       5
# 25937                       8                       5
# 25938                       8                       5
#
# [25939 rows x 9 columns]

# %%
df_cleaned = pd.concat([df_pipe,df_obj], axis =1)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25939 entries, 0 to 25938
# Data columns (total 39 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   DOF Gross Floor Area  (ft²)                                 25939 non-null  float64
#  1   2nd Largest Property Use - Gross Floor Area (ft²)           25939 non-null  float64
#  2   3rd Largest Property Use Type - Gross Floor Area (ft²)      25939 non-null  float64
#  3   Year Built                                                  25939 non-null  float64
#  4   Number of Buildings                                         25939 non-null  float64
#  5   Occupancy                                                   25939 non-null  float64
#  6   ENERGY STAR Score                                           25939 non-null  float64
#  7   Source EUI (kBtu/ft²)                                       25939 non-null  float64
#  8   Weather Normalized Source EUI (kBtu/ft²)                    25939 non-null  float64
#  9   Site EUI (kBtu/ft²)                                         25939 non-null  float64
#  10  Weather Normalized Site EUI (kBtu/ft²)                      25939 non-null  float64
#  11  Weather Normalized Site Electricity Intensity (kWh/ft²)     25939 non-null  float64
#  12  Weather Normalized Site Natural Gas Intensity (therms/ft²)  25939 non-null  float64
#  13  Fuel Oil #1 Use (kBtu)                                      25939 non-null  float64
#  14  Fuel Oil #2 Use (kBtu)                                      25939 non-null  float64
#  15  Fuel Oil #5 & 6 Use (kBtu)                                  25939 non-null  float64
#  16  Diesel #2 Use (kBtu)                                        25939 non-null  float64
#  17  District Steam Use (kBtu)                                   25939 non-null  float64
#  18  District Chilled Water Use (kBtu)                           25939 non-null  float64
#  19  Natural Gas Use (kBtu)                                      25939 non-null  float64
#  20  Weather Normalized Site Natural Gas Use (therms)            25939 non-null  float64
#  21  Electricity Use - Grid Purchase (kBtu)                      25939 non-null  float64
#  22  Electricity Use - Grid Purchase (kWh)                       25939 non-null  float64
#  23  Weather Normalized Site Electricity (kWh)                   25939 non-null  float64
#  24  Annual Maximum Demand (kW)                                  25939 non-null  float64
#  25  Total GHG Emissions (Metric Tons CO2e)                      25939 non-null  float64
#  26  Direct GHG Emissions (Metric Tons CO2e)                     25939 non-null  float64
#  27  Indirect GHG Emissions (Metric Tons CO2e)                   25939 non-null  float64
#  28  Water Use (All Water Sources) (kgal)                        25939 non-null  float64
#  29  Water Use Intensity (All Water Sources) (gal/ft²)           25939 non-null  float64
#  30  City Building                                               25939 non-null  int64
#  31  Borough                                                     25939 non-null  int64
#  32  Primary Property Type - Self Selected                       25939 non-null  int64
#  33  List of All Property Use Types at Property                  25939 non-null  int64
#  34  Largest Property Use Type                                   25939 non-null  int64
#  35  2nd Largest Property Use Type                               25939 non-null  int64
#  36  3rd Largest Property Use Type                               25939 non-null  int64
#  37  Metered Areas (Energy)                                      25939 non-null  int64
#  38  Metered Areas  (Water)                                      25939 non-null  int64
# dtypes: float64(30), int64(9)
# memory usage: 7.7 MB

# %% [markdown]
# # Feature Selection

# %%
# Selecting features and the target variable

Y_selection = df_cleaned['Total GHG Emissions (Metric Tons CO2e)']  #Target Feature
X_selection = df_cleaned.drop("Total GHG Emissions (Metric Tons CO2e)", 1)

# %%
# Partitioning the dataset into 2/3 training and 1/3 test set.
X_train_selection, X_test_selection, Y_train_selection, Y_test_selection = sklearn.model_selection.train_test_split(X_selection, Y_selection, test_size=0.33)

# Further splitting the training set into a validation set; 2/3 training set, and 1/3 validation set
X_train_selection, X_val_selection, Y_train_selection, Y_val_selection = sklearn.model_selection.train_test_split(X_train_selection, Y_train_selection, test_size=0.33)

# %%
# Feature Selection using XGBRegressor

X_data, y_label = make_regression(
    n_samples=X_train_selection.shape[0], n_features=X_train_selection.shape[1], n_informative=10, random_state=1
)
xgboost_model = XGBRegressor()
xgboost_model.fit(X_data, y_label)

feature_scores = []
feature_importances_xgboost = xgboost_model.feature_importances_
for index, importance_score in enumerate(feature_importances_xgboost):
    feature_scores.append([X_train_selection.columns[index], importance_score])

# %%
# List of features and their respective scores, depicting their importance

sorted_scores = sorted(np.array(feature_scores), key=lambda s: float(s[1]), reverse=True) 
print(np.array(sorted_scores))
# Out:
# [['Weather Normalized Site Electricity (kWh)' '0.17540875']
#  ['Site EUI (kBtu/ft²)' '0.1368753']
#  ['3rd Largest Property Use Type' '0.1244295']
#  ['Indirect GHG Emissions (Metric Tons CO2e)' '0.12201577']
#  ['Largest Property Use Type' '0.12166264']
#  ['Fuel Oil #5 & 6 Use (kBtu)' '0.09345414']
#  ['DOF Gross Floor Area  (ft²)' '0.06590423']
#  ['3rd Largest Property Use Type - Gross Floor Area (ft²)' '0.059950735']
#  ['List of All Property Use Types at Property' '0.057724368']
#  ['Diesel #2 Use (kBtu)' '0.0021826986']
#  ['Direct GHG Emissions (Metric Tons CO2e)' '0.0020963778']
#  ['Electricity Use - Grid Purchase (kBtu)' '0.0019719838']
#  ['2nd Largest Property Use Type' '0.0018877045']
#  ['Primary Property Type - Self Selected' '0.0017099641']
#  ['Natural Gas Use (kBtu)' '0.0016801067']
#  ['Metered Areas (Energy)' '0.001636952']
#  ['Weather Normalized Site Natural Gas Use (therms)' '0.0015644416']
#  ['Weather Normalized Site Natural Gas Intensity (therms/ft²)'
#   '0.0015633831']
#  ['Fuel Oil #2 Use (kBtu)' '0.0015599976']
#  ['Water Use (All Water Sources) (kgal)' '0.0015462441']
#  ['Borough' '0.001528822']
#  ['Weather Normalized Site EUI (kBtu/ft²)' '0.0014736751']
#  ['Water Use Intensity (All Water Sources) (gal/ft²)' '0.0014686917']
#  ['City Building' '0.0014645263']
#  ['District Steam Use (kBtu)' '0.0014637127']
#  ['District Chilled Water Use (kBtu)' '0.0014462012']
#  ['Electricity Use - Grid Purchase (kWh)' '0.0014439118']
#  ['Source EUI (kBtu/ft²)' '0.0012767841']
#  ['Fuel Oil #1 Use (kBtu)' '0.0012751078']
#  ['Weather Normalized Site Electricity Intensity (kWh/ft²)'
#   '0.0012525884']
#  ['Metered Areas  (Water)' '0.0012524847']
#  ['Number of Buildings' '0.0012433727']
#  ['Weather Normalized Source EUI (kBtu/ft²)' '0.0012378992']
#  ['ENERGY STAR Score' '0.0012275783']
#  ['Annual Maximum Demand (kW)' '0.0011325435']
#  ['Year Built' '0.0011139814']
#  ['2nd Largest Property Use - Gross Floor Area (ft²)' '0.0010130367']
#  ['Occupancy' '0.0008598197']]

# %%
features = pd.DataFrame(feature_scores, columns=['Features','Score'])
features.sort_values(by='Score', ascending=False).head(15)
# Out:
#                                              Features     Score
# 23          Weather Normalized Site Electricity (kWh)  0.175409
# 9                                 Site EUI (kBtu/ft²)  0.136875
# 35                      3rd Largest Property Use Type  0.124430
# 26          Indirect GHG Emissions (Metric Tons CO2e)  0.122016
# 33                          Largest Property Use Type  0.121663
# 15                         Fuel Oil #5 & 6 Use (kBtu)  0.093454
# 0                         DOF Gross Floor Area  (ft²)  0.065904
# 2   3rd Largest Property Use Type - Gross Floor Ar...  0.059951
# 32         List of All Property Use Types at Property  0.057724
# 16                               Diesel #2 Use (kBtu)  0.002183
# 25            Direct GHG Emissions (Metric Tons CO2e)  0.002096
# 21             Electricity Use - Grid Purchase (kBtu)  0.001972
# 34                      2nd Largest Property Use Type  0.001888
# 31              Primary Property Type - Self Selected  0.001710
# 19                             Natural Gas Use (kBtu)  0.001680

# %%
# Setting a score threshold of 0.002

Top_features = features[features['Score']>=0.002]
Top_features
# Out:
#                                              Features     Score
# 0                         DOF Gross Floor Area  (ft²)  0.065904
# 2   3rd Largest Property Use Type - Gross Floor Ar...  0.059951
# 9                                 Site EUI (kBtu/ft²)  0.136875
# 15                         Fuel Oil #5 & 6 Use (kBtu)  0.093454
# 16                               Diesel #2 Use (kBtu)  0.002183
# 23          Weather Normalized Site Electricity (kWh)  0.175409
# 25            Direct GHG Emissions (Metric Tons CO2e)  0.002096
# 26          Indirect GHG Emissions (Metric Tons CO2e)  0.122016
# 32         List of All Property Use Types at Property  0.057724
# 33                          Largest Property Use Type  0.121663
# 35                      3rd Largest Property Use Type  0.124430

# %%
# List of Top features

Top_features['Features'].tolist()
# Out:
# ['DOF Gross Floor Area  (ft²)',
#  '3rd Largest Property Use Type - Gross Floor Area (ft²)',
#  'Site EUI (kBtu/ft²)',
#  'Fuel Oil #5 & 6 Use (kBtu)',
#  'Diesel #2 Use (kBtu)',
#  'Weather Normalized Site Electricity (kWh)',
#  'Direct GHG Emissions (Metric Tons CO2e)',
#  'Indirect GHG Emissions (Metric Tons CO2e)',
#  'List of All Property Use Types at Property',
#  'Largest Property Use Type',
#  '3rd Largest Property Use Type']

# %% [markdown]
# # Checking for Multi-Collinearity

# %%
# VIF = 1, indicates no correlation between the independent variable and the other variables 
# VIF exceeding 5 or 10 indicates high multicollinearity between the independent variable and the others

def calc_vif(C):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = C.columns
    vif["VIF"] = [variance_inflation_factor(C.values, i) for i in range(C.shape[1])]

    return(vif)

# %%
X_selection[Top_features['Features'].tolist()]
# Out:
#        DOF Gross Floor Area  (ft²)  \
# 0                         734668.0
# 1                         380000.0
# 2                         646995.0
# 3                         405399.0
# 4                          56986.0
# ...                            ...
# 25934                     375225.0
# 25935                     375225.0
# 25936                      27424.0
# 25937                      43073.0
# 25938                      38912.0
#
#        3rd Largest Property Use Type - Gross Floor Area (ft²)  \
# 0                                                 5712.0
# 1                                                 2115.0
# 2                                                 2115.0
# 3                                                 2115.0
# 4                                                 2115.0
# ...                                                  ...
# 25934                                             8510.0
# 25935                                             8510.0
# 25936                                             8510.0
# 25937                                             8510.0
# 25938                                             8510.0
#
#        Site EUI (kBtu/ft²)  Fuel Oil #5 & 6 Use (kBtu)  Diesel #2 Use (kBtu)  \
# 0                     45.7                   2882919.0               69000.0
# 1                    101.0                   2882919.0               69000.0
# 2                     70.3                   2882919.0               69000.0
# 3                     97.1                   2882919.0               69000.0
# 4                    100.4                   2882919.0               69000.0
# ...                    ...                         ...                   ...
# 25934                 19.4                    478984.5            14322605.8
# 25935                 86.0                    478984.5            14322605.8
# 25936                107.1                    478984.5            14322605.8
# 25937                107.1                    478984.5            14322605.8
# 25938                299.4                    478984.5            14322605.8
#
#        Weather Normalized Site Electricity (kWh)  \
# 0                                      7032631.5
# 1                                      5055495.0
# 2                                      7446568.4
# 3                                      4612102.7
# 4                                     32021890.4
# ...                                          ...
# 25934                                   240845.8
# 25935                                  2709471.4
# 25936                                   489166.9
# 25937                                   201213.6
# 25938                                   382896.0
#
#        Direct GHG Emissions (Metric Tons CO2e)  \
# 0                                          0.0
# 1                                          0.0
# 2                                         51.2
# 3                                          0.0
# 4                                       1991.7
# ...                                        ...
# 25934                                    193.7
# 25935                                   1207.8
# 25936                                     66.7
# 25937                                     66.7
# 25938                                    748.8
#
#        Indirect GHG Emissions (Metric Tons CO2e)  \
# 0                                         2520.9
# 1                                         2895.1
# 2                                         3104.7
# 3                                         2826.2
# 4                                        10187.6
# ...                                          ...
# 25934                                        0.0
# 25935                                      806.2
# 25936                                      142.3
# 25937                                       58.1
# 25938                                      110.6
#
#        List of All Property Use Types at Property  Largest Property Use Type  \
# 0                                              86                         32
# 1                                              97                         32
# 2                                             325                         13
# 3                                             889                         32
# 4                                             973                         32
# ...                                           ...                        ...
# 25934                                         679                         29
# 25935                                         679                         29
# 25936                                         478                         19
# 25937                                         679                         29
# 25938                                         987                         33
#
#        3rd Largest Property Use Type
# 0                                 24
# 1                                  2
# 2                                  2
# 3                                  2
# 4                                  2
# ...                              ...
# 25934                             25
# 25935                             25
# 25936                             25
# 25937                             25
# 25938                             25
#
# [25939 rows x 11 columns]

# %%
C = X_selection[Top_features['Features'].tolist()].iloc[:,:]
calc_vif(C)
# Out:
#                                             variables        VIF
# 0                         DOF Gross Floor Area  (ft²)   1.432119
# 1   3rd Largest Property Use Type - Gross Floor Ar...   1.219515
# 2                                 Site EUI (kBtu/ft²)   5.524459
# 3                          Fuel Oil #5 & 6 Use (kBtu)   1.477446
# 4                                Diesel #2 Use (kBtu)   1.239906
# 5           Weather Normalized Site Electricity (kWh)   1.483562
# 6             Direct GHG Emissions (Metric Tons CO2e)   1.193485
# 7           Indirect GHG Emissions (Metric Tons CO2e)   5.494043
# 8          List of All Property Use Types at Property  33.208199
# 9                           Largest Property Use Type  29.140909
# 10                      3rd Largest Property Use Type   6.306261

# %% [markdown]
# High Correlations found between:
#     1) List of All Property Use Types at Property
#     2) Largest Property Use Type
#     3) 3rd Largest Property Use Type

# %%
# Uncorrellated top features

Top_feature = X_selection[['DOF Gross Floor Area  (ft²)',
 '3rd Largest Property Use Type - Gross Floor Area (ft²)',
 'Site EUI (kBtu/ft²)',
 'Fuel Oil #5 & 6 Use (kBtu)',
 'Diesel #2 Use (kBtu)',
 'Weather Normalized Site Electricity (kWh)',
 'Direct GHG Emissions (Metric Tons CO2e)',
 'Indirect GHG Emissions (Metric Tons CO2e)',
 'Largest Property Use Type']]

# %%
C = Top_feature.iloc[:,:]
calc_vif(C)
# Out:
#                                            variables       VIF
# 0                        DOF Gross Floor Area  (ft²)  1.429931
# 1  3rd Largest Property Use Type - Gross Floor Ar...  1.215762
# 2                                Site EUI (kBtu/ft²)  5.522052
# 3                         Fuel Oil #5 & 6 Use (kBtu)  1.458902
# 4                               Diesel #2 Use (kBtu)  1.233801
# 5          Weather Normalized Site Electricity (kWh)  1.467141
# 6            Direct GHG Emissions (Metric Tons CO2e)  1.191741
# 7          Indirect GHG Emissions (Metric Tons CO2e)  5.491215
# 8                          Largest Property Use Type  1.911331

# %%
# No Correlation observed

selected_df = X_selection[['DOF Gross Floor Area  (ft²)',
 '3rd Largest Property Use Type - Gross Floor Area (ft²)',
 'Site EUI (kBtu/ft²)',
 'Fuel Oil #5 & 6 Use (kBtu)',
 'Diesel #2 Use (kBtu)',
 'Weather Normalized Site Electricity (kWh)',
 'Direct GHG Emissions (Metric Tons CO2e)',
 'Indirect GHG Emissions (Metric Tons CO2e)',
 'Largest Property Use Type']]

# %%
selected_df
# Out:
#        DOF Gross Floor Area  (ft²)  \
# 0                         734668.0
# 1                         380000.0
# 2                         646995.0
# 3                         405399.0
# 4                          56986.0
# ...                            ...
# 25934                     375225.0
# 25935                     375225.0
# 25936                      27424.0
# 25937                      43073.0
# 25938                      38912.0
#
#        3rd Largest Property Use Type - Gross Floor Area (ft²)  \
# 0                                                 5712.0
# 1                                                 2115.0
# 2                                                 2115.0
# 3                                                 2115.0
# 4                                                 2115.0
# ...                                                  ...
# 25934                                             8510.0
# 25935                                             8510.0
# 25936                                             8510.0
# 25937                                             8510.0
# 25938                                             8510.0
#
#        Site EUI (kBtu/ft²)  Fuel Oil #5 & 6 Use (kBtu)  Diesel #2 Use (kBtu)  \
# 0                     45.7                   2882919.0               69000.0
# 1                    101.0                   2882919.0               69000.0
# 2                     70.3                   2882919.0               69000.0
# 3                     97.1                   2882919.0               69000.0
# 4                    100.4                   2882919.0               69000.0
# ...                    ...                         ...                   ...
# 25934                 19.4                    478984.5            14322605.8
# 25935                 86.0                    478984.5            14322605.8
# 25936                107.1                    478984.5            14322605.8
# 25937                107.1                    478984.5            14322605.8
# 25938                299.4                    478984.5            14322605.8
#
#        Weather Normalized Site Electricity (kWh)  \
# 0                                      7032631.5
# 1                                      5055495.0
# 2                                      7446568.4
# 3                                      4612102.7
# 4                                     32021890.4
# ...                                          ...
# 25934                                   240845.8
# 25935                                  2709471.4
# 25936                                   489166.9
# 25937                                   201213.6
# 25938                                   382896.0
#
#        Direct GHG Emissions (Metric Tons CO2e)  \
# 0                                          0.0
# 1                                          0.0
# 2                                         51.2
# 3                                          0.0
# 4                                       1991.7
# ...                                        ...
# 25934                                    193.7
# 25935                                   1207.8
# 25936                                     66.7
# 25937                                     66.7
# 25938                                    748.8
#
#        Indirect GHG Emissions (Metric Tons CO2e)  Largest Property Use Type
# 0                                         2520.9                         32
# 1                                         2895.1                         32
# 2                                         3104.7                         13
# 3                                         2826.2                         32
# 4                                        10187.6                         32
# ...                                          ...                        ...
# 25934                                        0.0                         29
# 25935                                      806.2                         29
# 25936                                      142.3                         19
# 25937                                       58.1                         29
# 25938                                      110.6                         33
#
# [25939 rows x 9 columns]

# %% [markdown]
# # Preparing data for Amazon SageMaker

# %%
X = selected_df
Y = df_cleaned['Total GHG Emissions (Metric Tons CO2e)']  #Target Feature

# %%
# Partitioning the dataset into 2/3 training and 1/3 test set.
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X, Y, test_size=0.33)

# Further splitting the training set into a validation set; 2/3 training set, and 1/3 validation set
X_train, X_val, Y_train, Y_val = sklearn.model_selection.train_test_split(X_train, Y_train, test_size=0.33)

# %% [markdown]
# For the Amazon SageMaker built-in XGBoost algorithm, the target feature column must be the first column in the dataframe.

# %%
train = pd.concat([Y_train, X_train], axis= 1)
val = pd.concat([Y_val, X_val], axis=1)
test = X_test

# %% [markdown]
# The 2017 and 2019 data have been cleaned using the preprocessing script, so they'd be imported from Amazon S3

# %%
dataset_2017 = 'cleaned_2017.csv'
dataset_2019 = 'cleaned_2019.csv'

# %%
data_2017 = pd.read_csv(f's3://{data_bucket}/{subfolder}/{dataset_2017}')
data_2019 = pd.read_csv(f's3://{data_bucket}/{subfolder}/{dataset_2019}')

# %%
data_2017 = data_2017.drop("Unnamed: 0", 1)
data_2019 = data_2019.drop("Unnamed: 0", 1)

# %%
#Preparing the 2017 and 2019 dataset for the model 

Y_2017 = data_2017['Total GHG Emissions (Metric Tons CO2e)'] # Target
X_2017 = data_2017.drop("Total GHG Emissions (Metric Tons CO2e)", 1)

Y_2019 = data_2019['Total GHG Emissions (Metric Tons CO2e)']  # Target
X_2019 = data_2019.drop("Total GHG Emissions (Metric Tons CO2e)", 1)

# %%
# Reducing the test sizes to 75%

X_train_2017, X_test_2017, Y_train_2017, Y_test_2017 = sklearn.model_selection.train_test_split(X_2017, Y_2017, test_size=0.75)
X_train_2019, X_test_2019, Y_train_2019, Y_test_2019 = sklearn.model_selection.train_test_split(X_2019, Y_2019, test_size=0.75)

# %% [markdown]
# # Converting Data to csv

# %%
train_file = train.to_csv(None, header=False, index=False).encode() # Doesn't include column header
train_file_header = train.to_csv(None, index=False).encode()
val_file = val.to_csv(None, header=False, index=False).encode() #Encode is to ensure text in csv is saved in the right format
test_file = test.to_csv(None, header=False, index=False).encode()
test_2017 = X_test_2017.to_csv(None, header=False, index=False).encode()
test_2019 = X_test_2019.to_csv(None, header=False, index=False).encode()

# %% [markdown]
# # Saving the CSV files to S3

# %%
with s3.open(f'{data_bucket}/{subfolder}/processed/train.csv', 'wb') as f:
    f.write(train_file)
with s3.open(f'{data_bucket}/{subfolder}/train_headers/train_data_with_headers.csv', 'wb') as f:
    f.write(train_file_header)
with s3.open(f'{data_bucket}/{subfolder}/processed/val.csv', 'wb') as f:
    f.write(val_file)
with s3.open(f'{data_bucket}/{subfolder}/processed/test.csv', 'wb') as f:
    f.write(test_file)
with s3.open(f'{data_bucket}/{subfolder}/processed/test_2017.csv', 'wb') as f:
    f.write(test_2017)
with s3.open(f'{data_bucket}/{subfolder}/processed/test_2019.csv', 'wb') as f:
    f.write(test_2019)

# %% [markdown]
# # File Location

# %%
raw_data_location = f's3://{data_bucket}/{subfolder}/{dataset}'
train_location = f's3://{data_bucket}/{subfolder}/processed/train.csv'
train_header_location = f's3://{data_bucket}/{subfolder}/train_headers/train_data_with_headers.csv'
val_location = f's3://{data_bucket}/{subfolder}/processed/val.csv'
test_location = f's3://{data_bucket}/{subfolder}/processed/test.csv'
test_2017_location = f's3://{data_bucket}/{subfolder}/processed/test_2017.csv'
test_2019_location = f's3://{data_bucket}/{subfolder}/processed/test_2019.csv'

# %% [markdown]
# # Preparing the CSV data for SageMaker

# %%
input_train = sagemaker.TrainingInput(s3_data=train_location, content_type="text/csv")
input_validation = sagemaker.TrainingInput(s3_data=val_location, content_type="text/csv")

# %%
# Copies test dataset from Amazon S3 into local folder.  

test_sample_path = test_2019_location
! aws s3 cp $test_sample_path .
# Out:
# download: s3://just-abdul-aws/NewYork/processed/test_2019.csv to ./test_2019.csv

# %% [markdown]
# # Creating SageMaker Experiment

# %% [markdown]
# Sagemaker experiment helps track preprocessing and training changes

# %%
# Create a SageMaker Experiment

create_date = strftime("%Y-%m-%d-%H-%M-%S")
LL_experiment = Experiment.create(experiment_name = "LL-Build-train-deploy-{}".format(create_date),
                                    description = "Predict GHG Emission from Energy and Water data",
                                   sagemaker_boto_client=sm,
                                    tags = [{'Key': 'LL-experiments', 'Value': 'NYC'}])
print(LL_experiment)
# Out:
# Experiment(sagemaker_boto_client=<botocore.client.SageMaker object at 0x7f347d53c0d0>,experiment_name='LL-Build-train-deploy-2021-06-26-07-32-29',description='Predict GHG Emission from Energy and Water data',tags=[{'Key': 'LL-experiments', 'Value': 'NYC'}],experiment_arn='arn:aws:sagemaker:us-east-2:077107849065:experiment/ll-build-train-deploy-2021-06-26-07-32-29',response_metadata={'RequestId': '37c28d59-51c6-488d-9e96-0a517e2b9c93', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '37c28d59-51c6-488d-9e96-0a517e2b9c93', 'content-type': 'application/x-amz-json-1.1', 'content-length': '113', 'date': 'Sat, 26 Jun 2021 07:32:28 GMT'}, 'RetryAttempts': 0})

# %%
# Start Tracking parameters used in the Pre-processing pipeline.

with Tracker.create(display_name="Preprocessing", sagemaker_boto_client=sm) as tracker:
    tracker.log_parameters({"train_test_split_ratio": 0.333, "random_state":0})
    # we can log the s3 uri to the dataset we just uploaded
    tracker.log_input(name="ccdefault-raw-dataset", media_type="s3/uri", value=raw_data_location)
    tracker.log_input(name="ccdefault-train-header-dataset", media_type="s3/uri", value=train_header_location)
    tracker.log_input(name="ccdefault-train-dataset", media_type="s3/uri", value=train_location)
    tracker.log_input(name="ccdefault-val-dataset", media_type="s3/uri", value=val_location)
    tracker.log_input(name="ccdefault-test-dataset", media_type="s3/uri", value=test_location)
    tracker.log_input(name="ccdefault-test2017-dataset", media_type="s3/uri", value=test_2017_location)
    tracker.log_input(name="ccdefault-test2019-dataset", media_type="s3/uri", value=test_2019_location)

# %% [markdown]
# # Training the Model

# %%
sess = sagemaker.Session()
from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(boto3.Session().region_name, 'linear-learner', 'latest')

# Tracking/Monitoring
preprocessing_trial_component = tracker.trial_component

trial_name = "NewYork-Training-job-{}".format(create_date)
Linear_trial = Trial.create(trial_name=trial_name, experiment_name=LL_experiment.experiment_name)

Linear_trial.add_trial_component(preprocessing_trial_component)
Linear_training_job_name = "NewYork-Training-job-{}".format(create_date)



Linear_Model = sagemaker.estimator.Estimator(
    container,
    role,
    instance_count=1,
    instance_type="ml.m5.large",
    output_path= f's3://{data_bucket}/{subfolder}/newmodel',
    sagemaker_session=sess)

# Setting-up Hyperparameter

Linear_Model.set_hyperparameters(
    feature_dim=X_train.shape[1], 
    predictor_type="regressor", 
    mini_batch_size=100
    )
    
Linear_Model.fit({"train": input_train, "validation": input_validation}, wait=True, job_name=Linear_training_job_name,  
         experiment_config={"TrialName": Linear_trial.trial_name, #log training job in Trials for lineage
            "TrialComponentDisplayName": "Training"})
# Out:
# WARNING:sagemaker.deprecations:The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# WARNING:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: NewYork-Training-job-2021-06-26-07-32-29
# 2021-06-26 07:33:27 Starting - Starting the training job...
# 2021-06-26 07:33:50 Starting - Launching requested ML instancesProfilerReport-1624692807: InProgress
# ...
# 2021-06-26 07:34:15 Starting - Preparing the instances for training.........
# 2021-06-26 07:35:51 Downloading - Downloading input data...
# 2021-06-26 07:36:16 Training - Downloading the training image.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [06/26/2021 07:36:35 INFO 139888508823360] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [06/26/2021 07:36:35 INFO 139888508823360] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '9', 'predictor_type': 'regressor', 'mini_batch_size': '100'}
# [06/26/2021 07:36:35 INFO 139888508823360] Final configuration: {'mini_batch_size': '100', 'epochs': '15', 'feature_dim': '9', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [06/26/2021 07:36:35 WARNING 139888508823360] Loggers have already been setup.
# Process 1 is a worker.
# [06/26/2021 07:36:35 INFO 139888508823360] Using default worker.
# [06/26/2021 07:36:35 INFO 139888508823360] Checkpoint loading and saving are disabled.
# [06/26/2021 07:36:35 INFO 139888508823360] Create Store: local
# [06/26/2021 07:36:36 INFO 139888508823360] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f39f784aa90>
# [06/26/2021 07:36:36 INFO 139888508823360] Scaling model computed with parameters:
#  {'stdev_label':
# [3623.2014]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [2.6870212e+05 3.2489467e+04 8.1257556e+02 6.3119070e+06 1.1099452e+07
#  3.7376440e+06 1.9760282e+03 2.8964565e+03 8.6070185e+00]
# <NDArray 9 @cpu(0)>, 'mean_label':
# [781.1749]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [1.0588058e+05 1.3281690e+04 9.9697205e+01 4.4217065e+06 4.7132565e+06
#  1.1597504e+06 3.6611630e+02 4.1508878e+02 3.0309805e+01]
# <NDArray 9 @cpu(0)>}
# [06/26/2021 07:36:36 INFO 139888508823360] nvidia-smi: took 0.031 seconds to run.
# [06/26/2021 07:36:36 INFO 139888508823360] nvidia-smi identified 0 GPUs.
# [06/26/2021 07:36:36 INFO 139888508823360] Number of GPUs being used: 0
# #metrics {"StartTime": 1624692996.3188758, "EndTime": 1624692996.3189108, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 10200.0, "count": 1, "min": 10200, "max": 10200}, "Total Batches Seen": {"sum": 102.0, "count": 1, "min": 102, "max": 102}, "Max Records Seen Between Resets": {"sum": 10100.0, "count": 1, "min": 10100, "max": 10100}, "Max Batches Seen Between Resets": {"sum": 101.0, "count": 1, "min": 101, "max": 101}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# #metrics {"StartTime": 1624692998.6263304, "EndTime": 1624692998.6263838, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.3438838028316868, "count": 1, "min": 0.3438838028316868, "max": 0.3438838028316868}}}
#
# #metrics {"StartTime": 1624692998.6264513, "EndTime": 1624692998.6264637, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.438362591901216, "count": 1, "min": 0.438362591901216, "max": 0.438362591901216}}}
#
# #metrics {"StartTime": 1624692998.626503, "EndTime": 1624692998.6265125, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.3973255412100718, "count": 1, "min": 0.3973255412100718, "max": 0.3973255412100718}}}
#
# #metrics {"StartTime": 1624692998.626543, "EndTime": 1624692998.6265512, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.3402881351627153, "count": 1, "min": 0.3402881351627153, "max": 0.3402881351627153}}}
#
# #metrics {"StartTime": 1624692998.6265812, "EndTime": 1624692998.6265886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.07045994938832932, "count": 1, "min": 0.07045994938832932, "max": 0.07045994938832932}}}
#
# #metrics {"StartTime": 1624692998.6266167, "EndTime": 1624692998.626624, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.4374950310305275, "count": 1, "min": 0.4374950310305275, "max": 0.4374950310305275}}}
#
# #metrics {"StartTime": 1624692998.6266522, "EndTime": 1624692998.6266603, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.5657090100106494, "count": 1, "min": 0.5657090100106494, "max": 0.5657090100106494}}}
#
# #metrics {"StartTime": 1624692998.6266925, "EndTime": 1624692998.6267006, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.0741207224464622, "count": 1, "min": 0.0741207224464622, "max": 0.0741207224464622}}}
#
# #metrics {"StartTime": 1624692998.626729, "EndTime": 1624692998.6267366, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.4115467572623286, "count": 1, "min": 0.4115467572623286, "max": 0.4115467572623286}}}
#
# #metrics {"StartTime": 1624692998.626786, "EndTime": 1624692998.626795, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.3561368727606946, "count": 1, "min": 0.3561368727606946, "max": 0.3561368727606946}}}
#
# #metrics {"StartTime": 1624692998.6268253, "EndTime": 1624692998.626833, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.4268446210206583, "count": 1, "min": 0.4268446210206583, "max": 0.4268446210206583}}}
#
# #metrics {"StartTime": 1624692998.6268623, "EndTime": 1624692998.626871, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.4074964507617827, "count": 1, "min": 0.4074964507617827, "max": 0.4074964507617827}}}
#
# #metrics {"StartTime": 1624692998.6269033, "EndTime": 1624692998.6269124, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.32573451632055744, "count": 1, "min": 0.32573451632055744, "max": 0.32573451632055744}}}
#
# #metrics {"StartTime": 1624692998.626944, "EndTime": 1624692998.6269531, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.12656997505671763, "count": 1, "min": 0.12656997505671763, "max": 0.12656997505671763}}}
#
# #metrics {"StartTime": 1624692998.6269877, "EndTime": 1624692998.626997, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.1458754796303552, "count": 1, "min": 0.1458754796303552, "max": 0.1458754796303552}}}
#
# #metrics {"StartTime": 1624692998.627031, "EndTime": 1624692998.6270401, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.38092633200359755, "count": 1, "min": 0.38092633200359755, "max": 0.38092633200359755}}}
#
# #metrics {"StartTime": 1624692998.6270742, "EndTime": 1624692998.6270833, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.6553986914712807, "count": 1, "min": 0.6553986914712807, "max": 0.6553986914712807}}}
#
# #metrics {"StartTime": 1624692998.6271174, "EndTime": 1624692998.6271265, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.5929684419416148, "count": 1, "min": 0.5929684419416148, "max": 0.5929684419416148}}}
#
# #metrics {"StartTime": 1624692998.6271605, "EndTime": 1624692998.62717, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.5934551904273444, "count": 1, "min": 0.5934551904273444, "max": 0.5934551904273444}}}
#
# #metrics {"StartTime": 1624692998.627204, "EndTime": 1624692998.6272135, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.617142942964003, "count": 1, "min": 0.617142942964003, "max": 0.617142942964003}}}
#
# #metrics {"StartTime": 1624692998.6272466, "EndTime": 1624692998.6272554, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.6220216121550264, "count": 1, "min": 0.6220216121550264, "max": 0.6220216121550264}}}
#
# #metrics {"StartTime": 1624692998.6272876, "EndTime": 1624692998.6272967, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.6631229957886811, "count": 1, "min": 0.6631229957886811, "max": 0.6631229957886811}}}
#
# #metrics {"StartTime": 1624692998.627328, "EndTime": 1624692998.627337, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.6385355894524476, "count": 1, "min": 0.6385355894524476, "max": 0.6385355894524476}}}
#
# #metrics {"StartTime": 1624692998.6273677, "EndTime": 1624692998.627376, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.6443166598677635, "count": 1, "min": 0.6443166598677635, "max": 0.6443166598677635}}}
#
# #metrics {"StartTime": 1624692998.6274068, "EndTime": 1624692998.627416, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9565689725505895, "count": 1, "min": 0.9565689725505895, "max": 0.9565689725505895}}}
#
# #metrics {"StartTime": 1624692998.6274486, "EndTime": 1624692998.6274567, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9470588646777744, "count": 1, "min": 0.9470588646777744, "max": 0.9470588646777744}}}
#
# #metrics {"StartTime": 1624692998.6274886, "EndTime": 1624692998.6274962, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9423819337733861, "count": 1, "min": 0.9423819337733861, "max": 0.9423819337733861}}}
#
# #metrics {"StartTime": 1624692998.6275303, "EndTime": 1624692998.6275387, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.949384943503758, "count": 1, "min": 0.949384943503758, "max": 0.949384943503758}}}
#
# #metrics {"StartTime": 1624692998.62757, "EndTime": 1624692998.6275795, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.0004517143656468, "count": 1, "min": 1.0004517143656468, "max": 1.0004517143656468}}}
#
# #metrics {"StartTime": 1624692998.6276138, "EndTime": 1624692998.6276233, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.994991318809575, "count": 1, "min": 0.994991318809575, "max": 0.994991318809575}}}
#
# #metrics {"StartTime": 1624692998.6276586, "EndTime": 1624692998.6276681, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.0069048668906606, "count": 1, "min": 1.0069048668906606, "max": 1.0069048668906606}}}
#
# #metrics {"StartTime": 1624692998.6277027, "EndTime": 1624692998.627712, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.0106698537283931, "count": 1, "min": 1.0106698537283931, "max": 1.0106698537283931}}}
#
# [06/26/2021 07:36:38 INFO 139888508823360] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.3438838028316868
# #metrics {"StartTime": 1624692999.2921147, "EndTime": 1624692999.2921684, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 543109.1100069735, "count": 1, "min": 543109.1100069735, "max": 543109.1100069735}}}
#
# #metrics {"StartTime": 1624692999.2922359, "EndTime": 1624692999.2922502, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 490707.8988406555, "count": 1, "min": 490707.8988406555, "max": 490707.8988406555}}}
#
# #metrics {"StartTime": 1624692999.2922878, "EndTime": 1624692999.2922966, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 590334.1295327755, "count": 1, "min": 590334.1295327755, "max": 590334.1295327755}}}
#
# #metrics {"StartTime": 1624692999.2923284, "EndTime": 1624692999.292358, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 561060.6569037657, "count": 1, "min": 561060.6569037657, "max": 561060.6569037657}}}
#
# #metrics {"StartTime": 1624692999.2923927, "EndTime": 1624692999.2924006, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 483495.24524930265, "count": 1, "min": 483495.24524930265, "max": 483495.24524930265}}}
#
# #metrics {"StartTime": 1624692999.2924528, "EndTime": 1624692999.2924645, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 3398227.250348675, "count": 1, "min": 3398227.250348675, "max": 3398227.250348675}}}
#
# #metrics {"StartTime": 1624692999.2925215, "EndTime": 1624692999.292532, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 2431057.0658995816, "count": 1, "min": 2431057.0658995816, "max": 2431057.0658995816}}}
#
# #metrics {"StartTime": 1624692999.2925642, "EndTime": 1624692999.2925723, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 1400195.0641562063, "count": 1, "min": 1400195.0641562063, "max": 1400195.0641562063}}}
#
# #metrics {"StartTime": 1624692999.2926025, "EndTime": 1624692999.2926116, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 564079.233568689, "count": 1, "min": 564079.233568689, "max": 564079.233568689}}}
#
# #metrics {"StartTime": 1624692999.2926583, "EndTime": 1624692999.292668, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 477945.2899232915, "count": 1, "min": 477945.2899232915, "max": 477945.2899232915}}}
#
# #metrics {"StartTime": 1624692999.2927198, "EndTime": 1624692999.2927325, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 696494.985181311, "count": 1, "min": 696494.985181311, "max": 696494.985181311}}}
#
# #metrics {"StartTime": 1624692999.2927694, "EndTime": 1624692999.2927969, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 645612.7478207811, "count": 1, "min": 645612.7478207811, "max": 645612.7478207811}}}
#
# #metrics {"StartTime": 1624692999.2928352, "EndTime": 1624692999.2928455, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 1109554.581241283, "count": 1, "min": 1109554.581241283, "max": 1109554.581241283}}}
#
# #metrics {"StartTime": 1624692999.292897, "EndTime": 1624692999.292908, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 2719797.7646443513, "count": 1, "min": 2719797.7646443513, "max": 2719797.7646443513}}}
#
# #metrics {"StartTime": 1624692999.2929406, "EndTime": 1624692999.2929492, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 1887292.9832635983, "count": 1, "min": 1887292.9832635983, "max": 1887292.9832635983}}}
#
# #metrics {"StartTime": 1624692999.2929826, "EndTime": 1624692999.2929912, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 1375286.55055788, "count": 1, "min": 1375286.55055788, "max": 1375286.55055788}}}
#
# #metrics {"StartTime": 1624692999.2930224, "EndTime": 1624692999.2930305, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 1172681.4222454673, "count": 1, "min": 1172681.4222454673, "max": 1172681.4222454673}}}
#
# #metrics {"StartTime": 1624692999.2930772, "EndTime": 1624692999.2930882, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 901035.6380753138, "count": 1, "min": 901035.6380753138, "max": 901035.6380753138}}}
#
# #metrics {"StartTime": 1624692999.2931244, "EndTime": 1624692999.293152, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 998915.6582112971, "count": 1, "min": 998915.6582112971, "max": 998915.6582112971}}}
#
# #metrics {"StartTime": 1624692999.2931917, "EndTime": 1624692999.293202, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 984889.4112622036, "count": 1, "min": 984889.4112622036, "max": 984889.4112622036}}}
#
# #metrics {"StartTime": 1624692999.2932563, "EndTime": 1624692999.2932668, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 668281.7754532775, "count": 1, "min": 668281.7754532775, "max": 668281.7754532775}}}
#
# #metrics {"StartTime": 1624692999.2933173, "EndTime": 1624692999.293329, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 715254.2508716875, "count": 1, "min": 715254.2508716875, "max": 715254.2508716875}}}
#
# #metrics {"StartTime": 1624692999.293365, "EndTime": 1624692999.2933736, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 632634.3375174338, "count": 1, "min": 632634.3375174338, "max": 632634.3375174338}}}
#
# #metrics {"StartTime": 1624692999.2934048, "EndTime": 1624692999.293414, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 668249.1316248256, "count": 1, "min": 668249.1316248256, "max": 668249.1316248256}}}
#
# #metrics {"StartTime": 1624692999.2934465, "EndTime": 1624692999.2934551, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 3167847.101464435, "count": 1, "min": 3167847.101464435, "max": 3167847.101464435}}}
#
# #metrics {"StartTime": 1624692999.2934868, "EndTime": 1624692999.2934952, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 3146985.74930265, "count": 1, "min": 3146985.74930265, "max": 3146985.74930265}}}
#
# #metrics {"StartTime": 1624692999.2935448, "EndTime": 1624692999.2935562, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 3143165.939330544, "count": 1, "min": 3143165.939330544, "max": 3143165.939330544}}}
#
# #metrics {"StartTime": 1624692999.2936106, "EndTime": 1624692999.2936223, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 3148959.9944211994, "count": 1, "min": 3148959.9944211994, "max": 3148959.9944211994}}}
#
# #metrics {"StartTime": 1624692999.2936606, "EndTime": 1624692999.293687, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 3316095.029288703, "count": 1, "min": 3316095.029288703, "max": 3316095.029288703}}}
#
# #metrics {"StartTime": 1624692999.2937267, "EndTime": 1624692999.2937365, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 3485961.8762203627, "count": 1, "min": 3485961.8762203627, "max": 3485961.8762203627}}}
#
# #metrics {"StartTime": 1624692999.2937887, "EndTime": 1624692999.2937999, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 3297414.2025801954, "count": 1, "min": 3297414.2025801954, "max": 3297414.2025801954}}}
#
# #metrics {"StartTime": 1624692999.2938352, "EndTime": 1624692999.2938442, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 3443829.711994421, "count": 1, "min": 3443829.711994421, "max": 3443829.711994421}}}
#
# [06/26/2021 07:36:39 INFO 139888508823360] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=543109.1100069735
# [06/26/2021 07:36:39 INFO 139888508823360] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=477945.2899232915
# [06/26/2021 07:36:39 INFO 139888508823360] Epoch 0: Loss improved. Updating best model
# [06/26/2021 07:36:39 INFO 139888508823360] Saving model for epoch: 0
# [06/26/2021 07:36:39 INFO 139888508823360] Saved checkpoint to "/tmp/tmpeuxws02n/mx-mod-0000.params"
# [06/26/2021 07:36:39 INFO 139888508823360] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1624692996.3193448, "EndTime": 1624692999.303164, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 21843.0, "count": 1, "min": 21843, "max": 21843}, "Total Batches Seen": {"sum": 219.0, "count": 1, "min": 219, "max": 219}, "Max Records Seen Between Resets": {"sum": 11643.0, "count": 1, "min": 11643, "max": 11643}, "Max Batches Seen Between Resets": {"sum": 117.0, "count": 1, "min": 117, "max": 117}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 11643.0, "count": 1, "min": 11643, "max": 11643}, "Number of Batches Since Last Reset": {"sum": 117.0, "count": 1, "min": 117, "max": 117}}}
#
# [06/26/2021 07:36:39 INFO 139888508823360] #throughput_metric: host=algo-1, train throughput=3901.8707979565033 records/second
# #metrics {"StartTime": 1624693002.5068629, "EndTime": 1624693002.5069091, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.1838057245930721, "count": 1, "min": 0.1838057245930721, "max": 0.1838057245930721}}}
#
# #metrics {"StartTime": 1624693002.506972, "EndTime": 1624693002.5071487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.2445914085992965, "count": 1, "min": 0.2445914085992965, "max": 0.2445914085992965}}}
#
# #metrics {"StartTime": 1624693002.507208, "EndTime": 1624693002.507223, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.19887698621071617, "count": 1, "min": 0.19887698621071617, "max": 0.19887698621071617}}}
#
# #metrics {"StartTime": 1624693002.5072584, "EndTime": 1624693002.5072691, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.14842787173094935, "count": 1, "min": 0.14842787173094935, "max": 0.14842787173094935}}}
#
# #metrics {"StartTime": 1624693002.5073142, "EndTime": 1624693002.5073247, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 1.0078876156128687, "count": 1, "min": 1.0078876156128687, "max": 1.0078876156128687}}}
#
# #metrics {"StartTime": 1624693002.5073617, "EndTime": 1624693002.507371, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 1.4370106627817811, "count": 1, "min": 1.4370106627817811, "max": 1.4370106627817811}}}
#
# #metrics {"StartTime": 1624693002.5074055, "EndTime": 1624693002.5074148, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.9474385161286798, "count": 1, "min": 0.9474385161286798, "max": 0.9474385161286798}}}
#
# #metrics {"StartTime": 1624693002.5074484, "EndTime": 1624693002.5074573, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 1.0206299158005878, "count": 1, "min": 1.0206299158005878, "max": 1.0206299158005878}}}
#
# #metrics {"StartTime": 1624693002.5074878, "EndTime": 1624693002.5074966, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.23336043386109945, "count": 1, "min": 0.23336043386109945, "max": 0.23336043386109945}}}
#
# #metrics {"StartTime": 1624693002.5077195, "EndTime": 1624693002.507736, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.16636001370333392, "count": 1, "min": 0.16636001370333392, "max": 0.16636001370333392}}}
#
# #metrics {"StartTime": 1624693002.5077858, "EndTime": 1624693002.5077975, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.24752794940923822, "count": 1, "min": 0.24752794940923822, "max": 0.24752794940923822}}}
#
# #metrics {"StartTime": 1624693002.5078328, "EndTime": 1624693002.5078428, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.1956747724828792, "count": 1, "min": 0.1956747724828792, "max": 0.1956747724828792}}}
#
# #metrics {"StartTime": 1624693002.5079625, "EndTime": 1624693002.5079777, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 1.1379529776989386, "count": 1, "min": 1.1379529776989386, "max": 1.1379529776989386}}}
#
# #metrics {"StartTime": 1624693002.5080528, "EndTime": 1624693002.5080652, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.32667114706388833, "count": 1, "min": 0.32667114706388833, "max": 0.32667114706388833}}}
#
# #metrics {"StartTime": 1624693002.5081015, "EndTime": 1624693002.508112, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 1.2567338593252775, "count": 1, "min": 1.2567338593252775, "max": 1.2567338593252775}}}
#
# #metrics {"StartTime": 1624693002.508157, "EndTime": 1624693002.508168, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 1.3943758771131778, "count": 1, "min": 1.3943758771131778, "max": 1.3943758771131778}}}
#
# #metrics {"StartTime": 1624693002.5082014, "EndTime": 1624693002.5082111, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.4241185536518179, "count": 1, "min": 0.4241185536518179, "max": 0.4241185536518179}}}
#
# #metrics {"StartTime": 1624693002.508245, "EndTime": 1624693002.50835, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.4114655854822747, "count": 1, "min": 0.4114655854822747, "max": 0.4114655854822747}}}
#
# #metrics {"StartTime": 1624693002.5083952, "EndTime": 1624693002.5084062, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.3908348630869697, "count": 1, "min": 0.3908348630869697, "max": 0.3908348630869697}}}
#
# #metrics {"StartTime": 1624693002.508442, "EndTime": 1624693002.5085366, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.4208688983244115, "count": 1, "min": 0.4208688983244115, "max": 0.4208688983244115}}}
#
# #metrics {"StartTime": 1624693002.5085866, "EndTime": 1624693002.5086, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.34840829610953045, "count": 1, "min": 0.34840829610953045, "max": 0.34840829610953045}}}
#
# #metrics {"StartTime": 1624693002.5086453, "EndTime": 1624693002.5086565, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.39954669960100075, "count": 1, "min": 0.39954669960100075, "max": 0.39954669960100075}}}
#
# #metrics {"StartTime": 1624693002.5087464, "EndTime": 1624693002.5087597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.3397361016787332, "count": 1, "min": 0.3397361016787332, "max": 0.3397361016787332}}}
#
# #metrics {"StartTime": 1624693002.5087984, "EndTime": 1624693002.5088875, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.40507308764318967, "count": 1, "min": 0.40507308764318967, "max": 0.40507308764318967}}}
#
# #metrics {"StartTime": 1624693002.5089347, "EndTime": 1624693002.5089467, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9430055808404396, "count": 1, "min": 0.9430055808404396, "max": 0.9430055808404396}}}
#
# #metrics {"StartTime": 1624693002.508992, "EndTime": 1624693002.509003, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9433534696389889, "count": 1, "min": 0.9433534696389889, "max": 0.9433534696389889}}}
#
# #metrics {"StartTime": 1624693002.5090892, "EndTime": 1624693002.5091023, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9434278572633349, "count": 1, "min": 0.9434278572633349, "max": 0.9434278572633349}}}
#
# #metrics {"StartTime": 1624693002.5091398, "EndTime": 1624693002.509233, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.9433253767983667, "count": 1, "min": 0.9433253767983667, "max": 0.9433253767983667}}}
#
# #metrics {"StartTime": 1624693002.5092807, "EndTime": 1624693002.5092938, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 0.9701129909836013, "count": 1, "min": 0.9701129909836013, "max": 0.9701129909836013}}}
#
# #metrics {"StartTime": 1624693002.5093393, "EndTime": 1624693002.5093503, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.9719102322849734, "count": 1, "min": 0.9719102322849734, "max": 0.9719102322849734}}}
#
# #metrics {"StartTime": 1624693002.509465, "EndTime": 1624693002.5094795, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.9700641098926808, "count": 1, "min": 0.9700641098926808, "max": 0.9700641098926808}}}
#
# #metrics {"StartTime": 1624693002.509529, "EndTime": 1624693002.5095406, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.9716373972029522, "count": 1, "min": 0.9716373972029522, "max": 0.9716373972029522}}}
#
# [06/26/2021 07:36:42 INFO 139888508823360] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.1838057245930721
# #metrics {"StartTime": 1624693003.2452173, "EndTime": 1624693003.2452655, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 378567.2824703626, "count": 1, "min": 378567.2824703626, "max": 378567.2824703626}}}
#
# #metrics {"StartTime": 1624693003.2453334, "EndTime": 1624693003.2453473, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 328634.5743113668, "count": 1, "min": 328634.5743113668, "max": 328634.5743113668}}}
#
# #metrics {"StartTime": 1624693003.2453842, "EndTime": 1624693003.2453928, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 375501.64783821476, "count": 1, "min": 375501.64783821476, "max": 375501.64783821476}}}
#
# #metrics {"StartTime": 1624693003.2454233, "EndTime": 1624693003.2454317, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 340955.2914051604, "count": 1, "min": 340955.2914051604, "max": 340955.2914051604}}}
#
# #metrics {"StartTime": 1624693003.245462, "EndTime": 1624693003.2454693, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 1371162.04916318, "count": 1, "min": 1371162.04916318, "max": 1371162.04916318}}}
#
# #metrics {"StartTime": 1624693003.2454972, "EndTime": 1624693003.2455046, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 727444.8300209205, "count": 1, "min": 727444.8300209205, "max": 727444.8300209205}}}
#
# #metrics {"StartTime": 1624693003.2458477, "EndTime": 1624693003.2458684, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 781013.1509762901, "count": 1, "min": 781013.1509762901, "max": 781013.1509762901}}}
#
# #metrics {"StartTime": 1624693003.245936, "EndTime": 1624693003.2459493, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 4237984.187587169, "count": 1, "min": 4237984.187587169, "max": 4237984.187587169}}}
#
# #metrics {"StartTime": 1624693003.24599, "EndTime": 1624693003.2460017, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 388874.12739714084, "count": 1, "min": 388874.12739714084, "max": 388874.12739714084}}}
#
# #metrics {"StartTime": 1624693003.2460365, "EndTime": 1624693003.2460463, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 284989.56720711297, "count": 1, "min": 284989.56720711297, "max": 284989.56720711297}}}
#
# #metrics {"StartTime": 1624693003.2461267, "EndTime": 1624693003.2461388, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 496966.73910390516, "count": 1, "min": 496966.73910390516, "max": 496966.73910390516}}}
#
# #metrics {"StartTime": 1624693003.2461758, "EndTime": 1624693003.2461855, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 388775.5686018131, "count": 1, "min": 388775.5686018131, "max": 388775.5686018131}}}
#
# #metrics {"StartTime": 1624693003.2462187, "EndTime": 1624693003.2462282, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 823976.3584379358, "count": 1, "min": 823976.3584379358, "max": 823976.3584379358}}}
#
# #metrics {"StartTime": 1624693003.2463381, "EndTime": 1624693003.2463522, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 1887767.0749651324, "count": 1, "min": 1887767.0749651324, "max": 1887767.0749651324}}}
#
# #metrics {"StartTime": 1624693003.2463882, "EndTime": 1624693003.2463987, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 1367949.820781032, "count": 1, "min": 1367949.820781032, "max": 1367949.820781032}}}
#
# #metrics {"StartTime": 1624693003.2464323, "EndTime": 1624693003.2464418, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 1483300.9832635983, "count": 1, "min": 1483300.9832635983, "max": 1483300.9832635983}}}
#
# #metrics {"StartTime": 1624693003.246475, "EndTime": 1624693003.2464843, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 785168.2495641562, "count": 1, "min": 785168.2495641562, "max": 785168.2495641562}}}
#
# #metrics {"StartTime": 1624693003.2466276, "EndTime": 1624693003.24664, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 697691.7212343096, "count": 1, "min": 697691.7212343096, "max": 697691.7212343096}}}
#
# #metrics {"StartTime": 1624693003.2466753, "EndTime": 1624693003.2466848, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 694470.615237099, "count": 1, "min": 694470.615237099, "max": 694470.615237099}}}
#
# #metrics {"StartTime": 1624693003.2467172, "EndTime": 1624693003.2467268, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 733788.8394351464, "count": 1, "min": 733788.8394351464, "max": 733788.8394351464}}}
#
# #metrics {"StartTime": 1624693003.2468033, "EndTime": 1624693003.246818, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 706906.6917712692, "count": 1, "min": 706906.6917712692, "max": 706906.6917712692}}}
#
# #metrics {"StartTime": 1624693003.2468584, "EndTime": 1624693003.246868, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 826012.8136331938, "count": 1, "min": 826012.8136331938, "max": 826012.8136331938}}}
#
# #metrics {"StartTime": 1624693003.2469006, "EndTime": 1624693003.24691, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 711815.5240585774, "count": 1, "min": 711815.5240585774, "max": 711815.5240585774}}}
#
# #metrics {"StartTime": 1624693003.2469451, "EndTime": 1624693003.2469542, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 822739.8115411437, "count": 1, "min": 822739.8115411437, "max": 822739.8115411437}}}
#
# #metrics {"StartTime": 1624693003.2469873, "EndTime": 1624693003.2469954, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 3161765.8671548115, "count": 1, "min": 3161765.8671548115, "max": 3161765.8671548115}}}
#
# #metrics {"StartTime": 1624693003.2470298, "EndTime": 1624693003.2470386, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 3136256.709902371, "count": 1, "min": 3136256.709902371, "max": 3136256.709902371}}}
#
# #metrics {"StartTime": 1624693003.247072, "EndTime": 1624693003.2470818, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 3144748.2454672246, "count": 1, "min": 3144748.2454672246, "max": 3144748.2454672246}}}
#
# #metrics {"StartTime": 1624693003.247115, "EndTime": 1624693003.2471247, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 3142612.2241980475, "count": 1, "min": 3142612.2241980475, "max": 3142612.2241980475}}}
#
# ...
#
# #metrics {"StartTime": 1624693042.617305, "EndTime": 1624693042.6173136, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 0.9462996005600897, "count": 1, "min": 0.9462996005600897, "max": 0.9462996005600897}}}
#
# #metrics {"StartTime": 1624693042.6173463, "EndTime": 1624693042.6173549, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.9721285122427447, "count": 1, "min": 0.9721285122427447, "max": 0.9721285122427447}}}
#
# #metrics {"StartTime": 1624693042.617387, "EndTime": 1624693042.6173947, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.9463138515373756, "count": 1, "min": 0.9463138515373756, "max": 0.9463138515373756}}}
#
# #metrics {"StartTime": 1624693042.6174247, "EndTime": 1624693042.617434, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.9721109976850707, "count": 1, "min": 0.9721109976850707, "max": 0.9721109976850707}}}
#
# [06/26/2021 07:37:22 INFO 139888508823360] #quality_metric: host=algo-1, epoch=14, train mse_objective <loss>=0.014769045607475885
# #metrics {"StartTime": 1624693043.3419569, "EndTime": 1624693043.3420303, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 104554.82035608438, "count": 1, "min": 104554.82035608438, "max": 104554.82035608438}}}
#
# #metrics {"StartTime": 1624693043.3423536, "EndTime": 1624693043.3423805, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 102620.16341963041, "count": 1, "min": 102620.16341963041, "max": 102620.16341963041}}}
#
# #metrics {"StartTime": 1624693043.3426182, "EndTime": 1624693043.3426387, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 127300.14574616458, "count": 1, "min": 127300.14574616458, "max": 127300.14574616458}}}
#
# #metrics {"StartTime": 1624693043.3428595, "EndTime": 1624693043.3428943, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 72370.67280116807, "count": 1, "min": 72370.67280116807, "max": 72370.67280116807}}}
#
# #metrics {"StartTime": 1624693043.3431177, "EndTime": 1624693043.3431368, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 24617.713585251047, "count": 1, "min": 24617.713585251047, "max": 24617.713585251047}}}
#
# #metrics {"StartTime": 1624693043.3433533, "EndTime": 1624693043.3433728, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 647830.9653068341, "count": 1, "min": 647830.9653068341, "max": 647830.9653068341}}}
#
# #metrics {"StartTime": 1624693043.343598, "EndTime": 1624693043.3436182, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 39672.49673661959, "count": 1, "min": 39672.49673661959, "max": 39672.49673661959}}}
#
# #metrics {"StartTime": 1624693043.343835, "EndTime": 1624693043.3438547, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 825822.9314853556, "count": 1, "min": 825822.9314853556, "max": 825822.9314853556}}}
#
# #metrics {"StartTime": 1624693043.3444042, "EndTime": 1624693043.3444269, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 120747.09297637727, "count": 1, "min": 120747.09297637727, "max": 120747.09297637727}}}
#
# #metrics {"StartTime": 1624693043.344679, "EndTime": 1624693043.3447006, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 70628.4719098675, "count": 1, "min": 70628.4719098675, "max": 70628.4719098675}}}
#
# #metrics {"StartTime": 1624693043.3449087, "EndTime": 1624693043.3449304, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 100063.3915784083, "count": 1, "min": 100063.3915784083, "max": 100063.3915784083}}}
#
# #metrics {"StartTime": 1624693043.345171, "EndTime": 1624693043.3451915, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 95639.90878334205, "count": 1, "min": 95639.90878334205, "max": 95639.90878334205}}}
#
# #metrics {"StartTime": 1624693043.345414, "EndTime": 1624693043.3454344, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 11571.289134005623, "count": 1, "min": 11571.289134005623, "max": 11571.289134005623}}}
#
# #metrics {"StartTime": 1624693043.3456376, "EndTime": 1624693043.3456573, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 637588.4611227337, "count": 1, "min": 637588.4611227337, "max": 637588.4611227337}}}
#
# #metrics {"StartTime": 1624693043.3458793, "EndTime": 1624693043.3458993, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 19022.893242786784, "count": 1, "min": 19022.893242786784, "max": 19022.893242786784}}}
#
# #metrics {"StartTime": 1624693043.3461204, "EndTime": 1624693043.3461404, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 731598.8188633193, "count": 1, "min": 731598.8188633193, "max": 731598.8188633193}}}
#
# #metrics {"StartTime": 1624693043.346431, "EndTime": 1624693043.346464, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 474788.3944386332, "count": 1, "min": 474788.3944386332, "max": 474788.3944386332}}}
#
# #metrics {"StartTime": 1624693043.3466842, "EndTime": 1624693043.3467045, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 429019.50897838216, "count": 1, "min": 429019.50897838216, "max": 429019.50897838216}}}
#
# #metrics {"StartTime": 1624693043.3469558, "EndTime": 1624693043.3469763, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 471134.41736401676, "count": 1, "min": 471134.41736401676, "max": 471134.41736401676}}}
#
# #metrics {"StartTime": 1624693043.3472073, "EndTime": 1624693043.347228, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 429394.57888772665, "count": 1, "min": 429394.57888772665, "max": 429394.57888772665}}}
#
# #metrics {"StartTime": 1624693043.347722, "EndTime": 1624693043.3477666, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 318820.94194560667, "count": 1, "min": 318820.94194560667, "max": 318820.94194560667}}}
#
# #metrics {"StartTime": 1624693043.3478794, "EndTime": 1624693043.3479164, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 570726.6067817294, "count": 1, "min": 570726.6067817294, "max": 570726.6067817294}}}
#
# #metrics {"StartTime": 1624693043.3479896, "EndTime": 1624693043.3480136, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 318941.8768305439, "count": 1, "min": 318941.8768305439, "max": 318941.8768305439}}}
#
# #metrics {"StartTime": 1624693043.3480806, "EndTime": 1624693043.3480942, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 570703.8501569037, "count": 1, "min": 570703.8501569037, "max": 570703.8501569037}}}
#
# #metrics {"StartTime": 1624693043.3481562, "EndTime": 1624693043.3481688, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 3292696.562761506, "count": 1, "min": 3292696.562761506, "max": 3292696.562761506}}}
#
# #metrics {"StartTime": 1624693043.3482459, "EndTime": 1624693043.3482587, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 3141851.35181311, "count": 1, "min": 3141851.35181311, "max": 3141851.35181311}}}
#
# #metrics {"StartTime": 1624693043.348333, "EndTime": 1624693043.3483534, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 3291493.0662482567, "count": 1, "min": 3291493.0662482567, "max": 3291493.0662482567}}}
#
# #metrics {"StartTime": 1624693043.3484197, "EndTime": 1624693043.3484402, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 3141461.0045327754, "count": 1, "min": 3141461.0045327754, "max": 3141461.0045327754}}}
#
# #metrics {"StartTime": 1624693043.348498, "EndTime": 1624693043.3485348, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 3442394.1555090654, "count": 1, "min": 3442394.1555090654, "max": 3442394.1555090654}}}
#
# #metrics {"StartTime": 1624693043.3485765, "EndTime": 1624693043.348604, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 4266715.718270572, "count": 1, "min": 4266715.718270572, "max": 4266715.718270572}}}
#
# #metrics {"StartTime": 1624693043.3486435, "EndTime": 1624693043.348653, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 3441685.1844490934, "count": 1, "min": 3441685.1844490934, "max": 3441685.1844490934}}}
#
# #metrics {"StartTime": 1624693043.3487098, "EndTime": 1624693043.3487215, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 4264943.180613668, "count": 1, "min": 4264943.180613668, "max": 4264943.180613668}}}
#
# [06/26/2021 07:37:23 INFO 139888508823360] #quality_metric: host=algo-1, epoch=14, validation mse_objective <loss>=104554.82035608438
# [06/26/2021 07:37:23 INFO 139888508823360] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=11571.289134005623
# [06/26/2021 07:37:23 INFO 139888508823360] Saving model for epoch: 14
# [06/26/2021 07:37:23 INFO 139888508823360] Saved checkpoint to "/tmp/tmpzkczxaoq/mx-mod-0000.params"
# [06/26/2021 07:37:23 INFO 139888508823360] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1624693040.4793222, "EndTime": 1624693043.3559437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 184845.0, "count": 1, "min": 184845, "max": 184845}, "Total Batches Seen": {"sum": 1857.0, "count": 1, "min": 1857, "max": 1857}, "Max Records Seen Between Resets": {"sum": 11643.0, "count": 1, "min": 11643, "max": 11643}, "Max Batches Seen Between Resets": {"sum": 117.0, "count": 1, "min": 117, "max": 117}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 11643.0, "count": 1, "min": 11643, "max": 11643}, "Number of Batches Since Last Reset": {"sum": 117.0, "count": 1, "min": 117, "max": 117}}}
#
# [06/26/2021 07:37:23 INFO 139888508823360] #throughput_metric: host=algo-1, train throughput=4047.2266100673705 records/second
# [06/26/2021 07:37:23 WARNING 139888508823360] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [06/26/2021 07:37:23 WARNING 139888508823360] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [06/26/2021 07:37:24 INFO 139888508823360] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=11571.289134005623
# [06/26/2021 07:37:24 INFO 139888508823360] #validation_score (algo-1) : ('mse_objective', 11336.641255611488)
# [06/26/2021 07:37:24 INFO 139888508823360] #validation_score (algo-1) : ('mse', 11336.641255611488)
# [06/26/2021 07:37:24 INFO 139888508823360] #validation_score (algo-1) : ('absolute_loss', 27.772023220940117)
# [06/26/2021 07:37:24 INFO 139888508823360] #quality_metric: host=algo-1, validation mse_objective <loss>=11336.641255611488
# [06/26/2021 07:37:24 INFO 139888508823360] #quality_metric: host=algo-1, validation mse <loss>=11336.641255611488
# [06/26/2021 07:37:24 INFO 139888508823360] #quality_metric: host=algo-1, validation absolute_loss <loss>=27.772023220940117
# [06/26/2021 07:37:24 INFO 139888508823360] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.01, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [06/26/2021 07:37:24 INFO 139888508823360] Saved checkpoint to "/tmp/tmpn4bjuao7/mx-mod-0000.params"
# [06/26/2021 07:37:24 INFO 139888508823360] Test data is not provided.
# #metrics {"StartTime": 1624692995.4215837, "EndTime": 1624693044.247686, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 896.8114852905273, "count": 1, "min": 896.8114852905273, "max": 896.8114852905273}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 12.788772583007812, "count": 16, "min": 0.1800060272216797, "max": 1.2018680572509766}, "update.time": {"sum": 46984.281063079834, "count": 15, "min": 2791.018486022949, "max": 4232.713937759399}, "finalize.time": {"sum": 886.643648147583, "count": 1, "min": 886.643648147583, "max": 886.643648147583}, "setuptime": {"sum": 20.774364471435547, "count": 1, "min": 20.774364471435547, "max": 20.774364471435547}, "totaltime": {"sum": 49205.124855041504, "count": 1, "min": 49205.124855041504, "max": 49205.124855041504}}}
#
#
# 2021-06-26 07:37:52 Completed - Training job completed
# ProfilerReport-1624692807: NoIssuesFound
# Training seconds: 119
# Billable seconds: 119

# %% [markdown]
# # Batch Transform for offline inference

# %%
# %%time

Linear_transformer = Linear_Model.transformer(instance_count = 1, instance_type = 'ml.m5.large', accept = 'text/csv')
# Out:
# INFO:sagemaker:Creating model with name: linear-learner-2021-06-26-07-38-12-600
# CPU times: user 21.7 ms, sys: 0 ns, total: 21.7 ms
# Wall time: 394 ms

# %%
# %%time

Linear_transformer.transform(test_location, split_type='Line', content_type='text/csv')

# %%
Linear_transformer.wait()

# %%
# Specify's the batch output location

data_dir =  f's3://{data_bucket}/{subfolder}/processed/'

# !aws s3 cp --recursive $Linear_transformer.output_path $data_dir
# Out:
# copy: s3://sagemaker-us-east-2-077107849065/linear-learner-2021-06-26-07-38-13-001/test.csv.out to s3://just-abdul-aws/NewYork/processed/test.csv.out

# %% [markdown]
# # Reviewing Batch Transform Output

# %%
# Function to access the batch transform result

def get_csv_output_from_s3(s3uri, file_name):
    parsed_url = urlparse(s3uri)
    bucket_name = parsed_url.netloc
    prefix = parsed_url.path[1:]
    s3 = boto3.resource('s3')
    obj = s3.Object(bucket_name, '{}/{}'.format(prefix, file_name))
    return obj.get()["Body"].read().decode('utf-8')
pred = get_csv_output_from_s3(Linear_transformer.output_path, 'test.csv.out')
pred = pd.read_csv(io.StringIO(pred), sep=",", header=None)
pred
# Out:
#                 0
# 0      569.815125
# 1     2471.048096
# 2      508.671387
# 3      167.366013
# 4      261.943848
# ...           ...
# 8555    63.372627
# 8556   935.438354
# 8557     6.237604
# 8558   389.995972
# 8559   271.183960
#
# [8560 rows x 1 columns]

# %%
pred.columns = ['Prediction'] # Renaming the column
pred['Prediction'] = pred.Prediction.str.replace(r"[a-zA-Z]",'') # Removing the str.
pred['Prediction'] = pred.Prediction.str.replace(r'[{}\""\:]','') # Removing Special Character
pred['Prediction'] = pred['Prediction'].apply(pd.to_numeric)
pred
# Out:
#        Prediction
# 0      569.815125
# 1     2471.048096
# 2      508.671387
# 3      167.366013
# 4      261.943848
# ...           ...
# 8555    63.372627
# 8556   935.438354
# 8557     6.237604
# 8558   389.995972
# 8559   271.183960
#
# [8560 rows x 1 columns]

# %%
test_mae_linear = np.mean(np.abs(Y_test - pred['Prediction'].tolist()))
test_mae_baseline = np.mean(np.abs(Y_test - np.median(Y_train)))  ## training median as baseline predictor

print("Test MAE Baseline :", round(test_mae_baseline, 3))
print("Test MAE Linear:", round(test_mae_linear, 3))
# Out:
# Test MAE Baseline : 1461.564
# Test MAE Linear: 102.206

# %%
actual = Y_test
actual = actual.reset_index(drop=True)

# %%
model_result = pd.concat([pred,actual], axis=1)
model_result
# Out:
#        Prediction  Total GHG Emissions (Metric Tons CO2e)
# 0      569.815125                                   557.8
# 1     2471.048096                                  2542.9
# 2      508.671387                                   504.9
# 3      167.366013                                   198.3
# 4      261.943848                                   271.6
# ...           ...                                     ...
# 8555    63.372627                                    74.2
# 8556   935.438354                                   933.8
# 8557     6.237604                                    27.2
# 8558   389.995972                                   433.9
# 8559   271.183960                                   270.9
#
# [8560 rows x 2 columns]

# %%
# The Trained Model

from time import gmtime, strftime
from sagemaker.model import Model
from sagemaker.image_uris import retrieve

model_name = "Linear-Learner-Model-Monitor-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())
model_url = "s3://just-abdul-aws/NewYork/newmodel/linear-learner-2021-06-23-07-35-44-219/output/model.tar.gz"


image_uri = retrieve("linear-learner", boto3.Session().region_name, "latest")

model = Model(image_uri=image_uri, model_data=model_url, role=role)
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# WARNING:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.

# %% [markdown]
# # Retrieve real-time inference data (results) from endpoints

# %% [markdown]
# # Configuring datacapture to capture 100% of the inference payloads received by the endpoint and deploying the model

# %%
from sagemaker.model_monitor import DataCaptureConfig

s3_capture_upload_path = 's3://{}/{}/monitoring/newDC/datacapture'.format(data_bucket, subfolder)

endpoint_name = "LL-model-monitor-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())
print("EndpointName={}".format(endpoint_name))

data_capture_config = DataCaptureConfig(
    enable_capture=True, 
    sampling_percentage=100, 
    destination_s3_uri=s3_capture_upload_path, 
    capture_options = ["REQUEST"]

)

# Deploying the Model

predictor = Linear_Model.deploy(
    initial_instance_count=1,
    instance_type="ml.m4.xlarge",
    endpoint_name=endpoint_name,
    data_capture_config=data_capture_config,
)
# Out:
# INFO:sagemaker:Creating model with name: linear-learner-2021-06-26-07-49-39-583
# EndpointName=LL-model-monitor-2021-06-26-07-49-39
# INFO:sagemaker:Creating endpoint with name LL-model-monitor-2021-06-26-07-49-39
# ---------------!

# %%
from sagemaker.predictor import Predictor
from sagemaker.serializers import CSVSerializer
import time

predictor = Predictor(endpoint_name=endpoint_name, serializer=CSVSerializer())

# %%
# Invoke Endpoint to capture results based on the test-data sent to the Model 

runtime_client = boto3.client('sagemaker-runtime')


with s3.open(f'{data_bucket}/{subfolder}/processed/test.csv') as f:
    payload = f.read().strip()
    response = runtime_client.invoke_endpoint(
    EndpointName=predictor.endpoint_name, ContentType="text/csv", Body=payload
)
result = json.loads(response["Body"].read().decode())
Y_pred = np.array([r["score"] for r in result["predictions"]])

# %%
Y_pred = pd.DataFrame(Y_pred)
Y_pred.columns=['Prediction']

# %%
test_mae_linear = np.mean(np.abs(Y_test - Y_pred['Prediction'].tolist()))
test_mae_baseline = np.mean(np.abs(Y_test - np.median(Y_train)))  ## training median as baseline predictor

print("Test MAE Baseline :", round(test_mae_baseline, 3))
print("Test MAE Linear:", round(test_mae_linear, 3))
# Out:
# Test MAE Baseline : 1461.564
# Test MAE Linear: 102.206

# %% [markdown]
# # Testing the Model on the 2019 data

# %%
# %%time
from itertools import islice
import math
import struct
import boto3

runtime_client = boto3.client('sagemaker-runtime')


with s3.open(f'{data_bucket}/{subfolder}/processed/test_2019.csv') as f:
    payload = f.read().strip()
response = runtime_client.invoke_endpoint(
    EndpointName=predictor.endpoint, ContentType="text/csv", Body=payload
)
# Out:
# WARNING:sagemaker.deprecations:The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# CPU times: user 40.5 ms, sys: 7.38 ms, total: 47.9 ms
# Wall time: 477 ms

# %%
result_2019 = json.loads(response["Body"].read().decode())
pred_2019 = np.array([r["score"] for r in result_2019["predictions"]])

pred_2019 = pd.DataFrame(pred_2019)
pred_2019.columns=['Prediction']

#Evaluating the model on the 2019 data
test_mae_linear = np.mean(np.abs(Y_test_2019 - pred_2019['Prediction'].tolist()))
test_mae_baseline = np.mean(np.abs(Y_test_2019 - np.median(Y_train_2019)))  ## training median as baseline predictor

print("Test MAE Baseline :", round(test_mae_baseline, 3))
print("Test MAE Linear:", round(test_mae_linear, 3))
# Out:
# Test MAE Baseline : 586.107
# Test MAE Linear: 182.055

# %%
actual_2019 = Y_test_2019
actual_2019 = actual_2019.reset_index(drop=True)

# %%
result_2019 = pd.concat([pred_2019,actual_2019], axis=1)
result_2019
# Out:
#         Prediction  Total GHG Emissions (Metric Tons CO2e)
# 0       487.402191                                   481.4
# 1       355.717224                                   335.7
# 2      1151.969971                                  1126.0
# 3       448.382568                                   453.7
# 4        43.560131                                     0.0
# ...            ...                                     ...
# 20830  1807.272461                                  1185.5
# 20831   146.661255                                   153.8
# 20832   365.344299                                   289.0
# 20833   171.194366                                   186.9
# 20834   447.833649                                   406.6
#
# [20835 rows x 2 columns]

# %% [markdown]
# # Testing the Model on the 2017 data

# %%
# %%time
from itertools import islice
import math
import struct
import boto3

runtime_client = boto3.client('sagemaker-runtime')


with s3.open(f'{data_bucket}/{subfolder}/processed/test_2017.csv') as f:
    payload = f.read().strip()
response = runtime_client.invoke_endpoint(
    EndpointName=predictor.endpoint_name, ContentType="text/csv", Body=payload
)
# Out:
# CPU times: user 42.2 ms, sys: 4.48 ms, total: 46.7 ms
# Wall time: 547 ms

# %%
result_2017 = json.loads(response["Body"].read().decode())
pred_2017 = np.array([r["score"] for r in result_2017["predictions"]])

pred_2017 = pd.DataFrame(pred_2017)
pred_2017.columns=['Prediction']

# Evaluating the model on the 2017 data
test_mae_linear = np.mean(np.abs(Y_test_2017 - pred_2017['Prediction'].tolist()))
test_mae_baseline = np.mean(np.abs(Y_test_2017 - np.median(Y_train_2017)))  ## training median as baseline predictor

print("Test MAE Baseline :", round(test_mae_baseline, 3))
print("Test MAE Linear:", round(test_mae_linear, 3))
# Out:
# Test MAE Baseline : 146.415
# Test MAE Linear: 23971018.269

# %%
actual_2017 = Y_test_2017
actual_2017 = actual_2017.reset_index(drop=True)

# %%
result_2017 = pd.concat([pred_2017,actual_2017], axis=1)
result_2017
# Out:
#          Prediction  Total GHG Emissions (Metric Tons CO2e)
# 0      4.485686e+05                                   506.8
# 1      4.053576e+06                                   280.3
# 2      8.780939e+05                                   230.9
# 3      3.448236e+06                                   311.8
# 4      4.845730e+06                                   798.5
# ...             ...                                     ...
# 26010  2.956354e+06                                    52.6
# 26011  1.166531e+07                                   706.6
# 26012  5.052904e+06                                   402.7
# 26013  4.856892e+06                                   446.5
# 26014  1.063050e+07                                   578.6
#
# [26015 rows x 2 columns]

# %% [markdown]
# The model performed very poorly against the 2017 dataset, this can be due to the differences in the features selected, some features in the 2017 dataset were not present in 2019 dataset and viceversa.

# %% [markdown]
# # Monitoring

# %% [markdown]
# # Verify that Model Monitor is correctly capturing the incoming data.

# %%
# Extract the captured json files.

data_capture_prefix = '{}/monitoring'.format(subfolder)
s3_client = boto3.Session().client('s3')
current_endpoint_capture_prefix = '{}/newDC/datacapture/{}/AllTraffic'.format(data_capture_prefix, endpoint_name)
print(current_endpoint_capture_prefix)
result = s3_client.list_objects(Bucket=data_bucket, Prefix=current_endpoint_capture_prefix)
capture_files = [capture_file.get("Key") for capture_file in result.get('Contents')]
# Out:
# NewYork/monitoring/newDC/datacapture/LL-model-monitor-2021-06-26-07-49-39/AllTraffic

# %%
def get_obj_body(obj_key):
    return s3_client.get_object(Bucket=data_bucket, Key=obj_key).get("Body").read().decode("utf-8")


capture_file = get_obj_body(capture_files[-1])
print(capture_file[:2000])
# Out:
# {"captureData":{"endpointInput":{"observedContentType":"text/csv","mode":"INPUT","data":"73313.0,3000.0,127.7,0.0,0.0,735124.4,352.1,205.7,10\n383934.0,7457.0,85.8,26012250.6,69000.0,4525183.6,0.0,2542.9,32\n69590.0,13857.0,95.1,6875249.5,602797.8,288079.3,418.0,86.9,29\n36200.0,0.0,67.5,522165.0,20492310.3,335426.6,101.3,96.9,32\n33922.0,6234.0,107.5,1755900.0,0.0,512746.2,13.0,258.5,32\n40916.0,23200.0,17.4,0.0,0.0,163325.3,7.7,48.2,29\n50170.0,5343.0,79.6,5086026.6,0.0,237512.7,167.7,71.0,29\n39600.0,61709.0,84.0,3965668.0,0.0,139499.3,151.2,40.5,29\n100500.0,5000.0,160.1,34074.0,14322605.8,709304.3,725.8,205.8,29\n56986.0,6200.0,64.7,0.0,602797.8,390923.5,493.3,117.0,29\n56986.0,30000.0,88.9,2882919.0,151800.0,1139029.0,233.3,331.7,21\n39750.0,29601.0,71.4,5040436.2,20492310.3,963999.8,6.7,278.6,50\n26225.0,9561.0,366.2,2739775.5,20492310.3,613946.6,397.6,179.4,29\n114003.0,0.0,84.5,3185641.4,33120.0,580300.3,571.0,171.8,29\n56986.0,0.0,72.8,8342250.2,67204.2,777382.4,248.5,233.0,29\n135000.0,16000.0,96.0,26012250.6,69000.0,2482010.4,229.0,731.9,59\n47062.0,25806.0,106.6,0.0,2718599.9,679198.7,144.8,198.8,29\n56986.0,14596.0,84.8,0.0,2349450.1,2517504.2,336.5,2642.7,29\n130000.0,16418.0,103.0,8434640.4,0.0,734072.6,574.4,217.6,29\n119985.0,8000.0,77.2,8342250.2,2349450.1,535451.6,400.3,159.9,29\n35670.0,0.0,67.7,2999923.5,14322605.8,98408.0,119.2,28.9,29\n77502.0,2220.0,97.8,5690550.1,69000.0,1203450.8,181.0,347.8,18\n30400.0,9318.0,71.2,4950600.1,14322605.8,192295.9,78.9,57.4,29\n191009.0,16688.0,51.1,15750000.5,0.0,692600.5,531.4,200.1,29\n56986.0,3400.0,89.8,5250000.1,2718599.9,105920.1,187.3,31.2,29\n26403.0,4282.0,37.3,2379513.0,0.0,59999.3,41.1,17.8,29\n34554.0,2500.0,119.1,34074.0,14322605.8,183011.4,158.4,113.6,29\n62345.0,400.0,127.0,4225499.6,14322605.8,286929.3,391.6,86.4,29\n62612.0,3400.0,85.5,351678.0,2718599.9,854972.9,129.4,247.1,29\n56986.0,30000.0,76.4,2882919.0,151800.0,1532799.9,613.0,442.9,21\n93480.0,2777.0,76.8,8342250.2,67204.2,453424.1,2

# %%
import json

print(json.dumps(json.loads(capture_file.split("\n")[0]), indent=2))

# %%
# Copy over the training dataset to Amazon S3 (if you already have it in Amazon S3, you could reuse it)
prefix = "NewYork/LL-ModelMonitor"
baseline_prefix = prefix + "/baselining"
baseline_data_prefix = baseline_prefix + "/data"
baseline_results_prefix = baseline_prefix + "/results"

baseline_data_uri = f's3://{data_bucket}/{subfolder}/train_headers'
baseline_results_uri = "s3://{}/{}".format(data_bucket, baseline_results_prefix)
print("Baseline data uri: {}".format(baseline_data_uri))
print("Baseline results uri: {}".format(baseline_results_uri))
# Out:
# Baseline data uri: s3://just-abdul-aws/NewYork/train_headers
# Baseline results uri: s3://just-abdul-aws/NewYork/LL-ModelMonitor/baselining/results

# %% [markdown]
# # A baseline job for Model Monitor to capture the statistics of the training data

# %%
from sagemaker.model_monitor import DefaultModelMonitor
from sagemaker.model_monitor.dataset_format import DatasetFormat

my_default_monitor = DefaultModelMonitor(
    role=role,
    instance_count=1,
    instance_type="ml.m5.xlarge",
    volume_size_in_gb=20,
    max_runtime_in_seconds=3600,
)

my_default_monitor.suggest_baseline(
    baseline_dataset=baseline_data_uri + "/train_data_with_headers.csv",
    dataset_format=DatasetFormat.csv(header=True),
    output_s3_uri=baseline_results_uri,
    wait=True,
)

# %%
s3_client = boto3.Session().client("s3")
result = s3_client.list_objects(Bucket=data_bucket, Prefix=baseline_results_prefix)
report_files = [report_file.get("Key") for report_file in result.get("Contents")]
print("Found Files:")
print("\n ".join(report_files))
# Out:
# Found Files:
# NewYork/LL-ModelMonitor/baselining/results/constraints.json
#  NewYork/LL-ModelMonitor/baselining/results/statistics.json

# %% [markdown]
# # Explore the generated constraints and statistics

# %%
import pandas as pd

baseline_job = my_default_monitor.latest_baselining_job
schema_df = pd.io.json.json_normalize(baseline_job.baseline_statistics().body_dict["features"])
schema_df.head(10)
# Out:
#                                                 name inferred_type  \
# 0             Total GHG Emissions (Metric Tons CO2e)    Fractional
# 1                        DOF Gross Floor Area  (ft?)    Fractional
# 2  3rd Largest Property Use Type - Gross Floor Ar...    Fractional
# 3                                Site EUI (kBtu/ft?)    Fractional
# 4                         Fuel Oil #5 & 6 Use (kBtu)    Fractional
# 5                               Diesel #2 Use (kBtu)    Fractional
# 6          Weather Normalized Site Electricity (kWh)    Fractional
# 7            Direct GHG Emissions (Metric Tons CO2e)    Fractional
# 8          Indirect GHG Emissions (Metric Tons CO2e)    Fractional
# 9                          Largest Property Use Type      Integral
#
#    numerical_statistics.common.num_present  \
# 0                                    11643
# 1                                    11643
# 2                                    11643
# 3                                    11643
# 4                                    11643
# 5                                    11643
# 6                                    11643
# 7                                    11643
# 8                                    11643
# 9                                    11643
#
#    numerical_statistics.common.num_missing  numerical_statistics.mean  \
# 0                                        0               7.846720e+02
# 1                                        0               1.052343e+05
# 2                                        0               1.319773e+04
# 3                                        0               9.894273e+01
# 4                                        0               4.377923e+06
# 5                                        0               4.756486e+06
# 6                                        0               1.180632e+06
# 7                                        0               3.671790e+02
# 8                                        0               4.172567e+02
# 9                                        0               3.029262e+01
#
#    numerical_statistics.sum  numerical_statistics.std_dev  \
# 0              9.135936e+06                  3.543853e+03
# 1              1.225243e+09                  2.647070e+05
# 2              1.536612e+08                  3.243838e+04
# 3              1.151990e+06                  7.591152e+02
# 4              5.097215e+10                  6.219196e+06
# 5              5.537977e+10                  1.118877e+07
# 6              1.374610e+10                  3.991467e+06
# 7              4.275065e+06                  1.937453e+03
# 8              4.858120e+06                  2.778816e+03
# 9              3.526970e+05                  8.599150e+00
#
#    numerical_statistics.min  numerical_statistics.max  \
# 0                       0.0                  255266.2
# 1                   25006.0                13435076.0
# 2                       0.0                  892545.0
# 3                       0.0                   81057.5
# 4                       0.0                62991290.6
# 5                       0.0               120336347.0
# 6                       0.0               121990108.6
# 7                       0.0                  144497.3
# 8                    -281.1                  255266.2
# 9                       0.0                      72.0
#
#        numerical_statistics.distribution.kll.buckets  \
# 0  [{'lower_bound': 0.0, 'upper_bound': 25526.620...
# 1  [{'lower_bound': 25006.0, 'upper_bound': 13660...
# 2  [{'lower_bound': 0.0, 'upper_bound': 89254.5, ...
# 3  [{'lower_bound': 0.0, 'upper_bound': 8105.75, ...
# 4  [{'lower_bound': 0.0, 'upper_bound': 6299129.0...
# 5  [{'lower_bound': 0.0, 'upper_bound': 12033634....
# 6  [{'lower_bound': 0.0, 'upper_bound': 12199010....
# 7  [{'lower_bound': 0.0, 'upper_bound': 14449.73,...
# 8  [{'lower_bound': -281.1, 'upper_bound': 25273....
# 9  [{'lower_bound': 0.0, 'upper_bound': 7.2, 'cou...
#
#    numerical_statistics.distribution.kll.sketch.parameters.c  \
# 0                                               0.64
# 1                                               0.64
# 2                                               0.64
# 3                                               0.64
# 4                                               0.64
# 5                                               0.64
# 6                                               0.64
# 7                                               0.64
# 8                                               0.64
# 9                                               0.64
#
#    numerical_statistics.distribution.kll.sketch.parameters.k  \
# 0                                             2048.0
# 1                                             2048.0
# 2                                             2048.0
# 3                                             2048.0
# 4                                             2048.0
# 5                                             2048.0
# 6                                             2048.0
# 7                                             2048.0
# 8                                             2048.0
# 9                                             2048.0
#
#    numerical_statistics.distribution.kll.sketch.data
# 0  [[64.0, 537.6, 512.8, 3134.0, 1912.8, 359.3, 7...
# 1  [[51914.0, 64896.0, 97636.0, 311501.0, 56986.0...
# 2  [[6234.0, 3550.0, 10000.0, 12211.0, 30000.0, 0...
# 3  [[14.6, 96.9, 89.2, 123.0, 71.2, 101.4, 63.9, ...
# 4  [[1755900.0, 374999.9, 26012250.6, 2882919.0, ...
# 5  [[0.0, 602797.8, 69000.0, 151800.0, 151800.0, ...
# 6  [[219813.1, 282944.2, 429482.2, 4664864.2, 164...
# 7  [[0.0, 346.3, 385.9, 0.0, 1438.0, 298.1, 305.9...
# 8  [[64.0, 191.3, 126.9, 3134.0, 474.8, 61.3, 450...
# 9  [[29.0, 29.0, 29.0, 32.0, 21.0, 29.0, 29.0, 66...

# %%
constraints_df = pd.io.json.json_normalize(
    baseline_job.suggested_constraints().body_dict["features"]
)
constraints_df.head(10)
# Out:
#                                                 name inferred_type  \
# 0             Total GHG Emissions (Metric Tons CO2e)    Fractional
# 1                        DOF Gross Floor Area  (ft?)    Fractional
# 2  3rd Largest Property Use Type - Gross Floor Ar...    Fractional
# 3                                Site EUI (kBtu/ft?)    Fractional
# 4                         Fuel Oil #5 & 6 Use (kBtu)    Fractional
# 5                               Diesel #2 Use (kBtu)    Fractional
# 6          Weather Normalized Site Electricity (kWh)    Fractional
# 7            Direct GHG Emissions (Metric Tons CO2e)    Fractional
# 8          Indirect GHG Emissions (Metric Tons CO2e)    Fractional
# 9                          Largest Property Use Type      Integral
#
#    completeness  num_constraints.is_non_negative
# 0           1.0                             True
# 1           1.0                             True
# 2           1.0                             True
# 3           1.0                             True
# 4           1.0                             True
# 5           1.0                             True
# 6           1.0                             True
# 7           1.0                             True
# 8           1.0                            False
# 9           1.0                             True

# %% [markdown]
# # Set up endpoint monitoring frequency/timing

# %%
from sagemaker.model_monitor import CronExpressionGenerator
from time import gmtime, strftime

mon_schedule_name = "Linear-Learner-model-monitor-schedule-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

my_default_monitor.create_monitoring_schedule(
    monitor_schedule_name=mon_schedule_name,
    endpoint_input=predictor.endpoint,
    statistics=my_default_monitor.baseline_statistics(),
    constraints=my_default_monitor.suggested_constraints(),
    schedule_cron_expression=CronExpressionGenerator.hourly(),
    enable_cloudwatch_metrics=True,
)
# Out:
# WARNING:sagemaker.deprecations:The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# INFO:sagemaker.model_monitor.model_monitoring:Creating Monitoring Schedule with name: Linear-Learner-model-monitor-schedule-2021-06-26-08-09-58

# %% [markdown]
# # Start generating some artificial data traffic with the 2019 data

# %% [markdown]
# The cell below starts a thread to send some traffic to the endpoint. If there is no traffic, the monitoring jobs will be marked as Failed since there is no data to process.

# %%
from threading import Thread
from time import sleep
import time

endpoint_name = predictor.endpoint
runtime_client = boto3.client("runtime.sagemaker")

# (just repeating code from above for convenience/ able to run this section independently)
def invoke_endpoint(ep_name, runtime_client):
    with s3.open(f'{data_bucket}/{subfolder}/processed/test_2019.csv') as f:
        for row in f:
            payload = row.rstrip()
            response = runtime_client.invoke_endpoint(
                EndpointName=ep_name, ContentType="text/csv", Body=payload
            )
            response["Body"].read()
            time.sleep(1)


def invoke_endpoint_forever():
    while True:
        invoke_endpoint(endpoint_name, runtime_client)


thread = Thread(target=invoke_endpoint_forever)
thread.start()
# Out:
# WARNING:sagemaker.deprecations:The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# # Checking Monitoring Status

# %%
desc_schedule_result = my_default_monitor.describe_schedule()
print('Schedule status: {}'.format(desc_schedule_result['MonitoringScheduleStatus']))
# Out:
# Schedule status: Scheduled

# %%
# View Monitoring Schedule

executions = my_default_monitor.list_executions()
executions

# %%
latest_execution = executions[-1]

latest_execution.describe()['ProcessingJobStatus']
latest_execution.describe()['ExitMessage']
# Out:
# 'CompletedWithViolations: Job completed successfully with 1 violations.'

# %% [markdown]
# # Clean Up (Delete Monitoring Schedule and End Point)

# %%
# Deleting the Monitoring Schedule

my_default_monitor.delete_monitoring_schedule()
time.sleep(10)
# Out:
# Deleting Monitoring Schedule with name: Linear-Learner-model-monitor-schedule-2021-06-26-08-09-58
# INFO:sagemaker.model_monitor.model_monitoring:Deleting Data Quality Job Definition with name: data-quality-job-definition-2021-06-26-08-09-59-021

# %%
# Deleting the endpoint

sm.delete_endpoint(EndpointName = endpoint_name)
